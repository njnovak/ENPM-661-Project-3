# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from copy import deepcopy
import cv2
from cv2 import VideoWriter, VideoWriter_fourcc
import sys
import math

# %%
r = 0.033*20
L = 0.35*20

# %%
# node class that each spot in the map will occupy
# cell location and goal_location are tuples representing index 
# of current cell location and goal cell locations
# local path represents the path to get to this 
# node from the optimal parent node
class Node:
    def __init__(self, parent, cell_location, region, c2c, c2g, local_path, command):
        self.parent = parent
        self.cell_location = cell_location
        self.region = region
        self.c2c = c2c
        self.c2g = c2g
        self.h = c2c+c2g
        self.local_path = local_path
        self.command = command

# %%
# given 2 points of a line, retrun a lambda function which caluclates the 
# y value of an x
def generate_line_eq(p1, p2):
    
    x1 = p1[0]
    y1 = p1[1]
    
    x2 = p2[0]
    y2 = p2[1]
    
    m = (y2-y1)/(x2-x1)
    b = y1-m*x1
    
    lin_func = lambda x: m*x+b
    
    return lin_func

# %%
# hardcoded obstacles defined by their vertices and origins
# we just see if the current x and y are within bounding lines
def check_obstacle(x, y):
    
    # check bottom circle
    if y <= 60 and y >= 20 and x <= np.sqrt(20**2 - (y-40)**2) + 40 and x >= -np.sqrt(20**2 - (y-40)**2) + 40:
        return True

    #check top circle
    if y <= 180 and y >= 140 and x <= np.sqrt(20**2 - (y-160)**2) + 40 and x >= -np.sqrt(20**2 - (y-160)**2) + 40:
        return True

    # check left square
    if x >= 5 and x <= 35 and y >= 85 and y <= 115:
        return True

    # check middle rectangle
    if x >= 75 and x <= 125 and y >= 85 and y <= 115:
        return True

    # check right rectangle
    if x >= 145 and x <= 175 and y >= 40 and y <= 80:
        return True
    

    return False

# %%
# iterate over the board, and if the cell is an obstacle, generate 
# the a circle of points around it which are padding
def generate_margin(color_map, radius):

    height = len(color_map)
    width = len(color_map[0])

    for y in range(len(color_map)):
        for x in range(len(color_map[y])):

            # read the color map and check to see if the current space is an obstacle
            if (color_map[y][x][0] == 255 and color_map[y][x][1] == 0 and 
                color_map[y][x][2] == 0):

                # generate circle bounds for a point if it is an obstacle
                x_range = range(x-radius, x+radius+1)

                for x_i in x_range:
                    y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
                    y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

                    y_range = np.arange(y_lower_limit, y_upper_limit+1)
                    for y_i in y_range:
                        if (x_i >= 0 and x_i < width) and (y_i >= 0 and y_i < height):
                            if not (color_map[int(y_i)][x_i][0] == [255] and 
                                    color_map[int(y_i)][x_i][1] == [0] and 
                                    color_map[int(y_i)][x_i][2] == [0]):
                                color_map[int(y_i)][x_i] = [0,255,0]
    return color_map

# %%
# draw a circle (red in numpy, blue in opencv) to represent the acceptable goal zone
def expand_goal(color_map, goal_location, radius):

    x = goal_location[1]
    y = goal_location[0]

    height = len(color_map)
    width = len(color_map[0])

    x_range = range(x-radius, x+radius+1)
    for x_i in x_range:
        y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
        y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

        y_range = np.arange(y_lower_limit, y_upper_limit+1)
        for y_i in y_range:
            if (x_i >= 0 and x_i < width) and (y_i >= 0 and y_i < height):
                if not (int(color_map[int(y_i)][int(x_i)][0]) == 255 or\
                       int(color_map[int(y_i)][int(x_i)][1]) == 255):
                    color_map[int(y_i)][int(x_i)] = [0,0,255]

    return color_map

# %%
# read the board and depending on each nodes status
# write the proper color in a numpy array as BGR colors
def create_color_map(height, width, radius, goal_location):

    color_map = np.zeros(shape=[height, width, 3], dtype=np.uint8)

    for row in range(height):
        for col in range(width):
            if check_obstacle(col, row):
                color_map[row][col][0] = 255
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

            else:
                color_map[row][col][0] = 0
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

    color_map = expand_goal(color_map, goal_location, 5)
    color_map = generate_margin(color_map, 2)


    return color_map

# %%
# pass in color map coordinates and convert them to board 
# coordinates which have been compressed/expanded coordinates 
# by the neighborhood threshold
def compress_coordinates(x, y, theta, thresh):
    compressed_x = int(np.floor(x/thresh))
    compressed_y = int(np.floor(y/thresh))
    compressed_angle = 0 if theta == 0 else (int(np.floor(360/theta))-1)%12

    return compressed_x, compressed_y, compressed_angle

# %%
# will be used when iterating over closed nodes
# updates the previous color map given the current node to a specifies color
def update_color_map(curr_node, color_map, brg_color):

    row = int(np.floor(curr_node.cell_location[0]))
    col = int(np.floor(curr_node.cell_location[1]))

    color_map[row][col][0] = brg_color[0]
    color_map[row][col][1] = brg_color[1]
    color_map[row][col][2] = brg_color[2]

    return color_map

# %%
# create the board
# returns a 3d array
# dimensions are height width and angle. Takes in a compressed version of 
# the height width and angle which handles the region/node similarity
def create_board(width, height, thresh):

    compressed_width, compressed_height, compressed_angle = compress_coordinates(x=width, y=height, theta=30, thresh=thresh)

    board = []
    for row_num in range(0, compressed_height):
        temp_row = []
        for col_num in range(0, compressed_width):

            temp_configuration = []
            for angle in range(0,compressed_angle+1):

                c2c = np.Infinity
                c2g = np.Infinity

                # c2g = np.sqrt((row_num-goal_location[0])**2 + (col_num-goal_location[1]**2))

                new_node = Node(parent=None, 
                                c2c=c2c,
                                c2g=c2g,
                                cell_location=[int(row_num*thresh), int(col_num*thresh), angle],
                                region=[row_num, col_num, angle],
                                local_path=[],
                                command = None)

                temp_configuration.append(new_node)
            temp_row.append(temp_configuration)
        board.append(temp_row)

    return board

# %%
# generates a series of x and y values representing a curve given wheel velocities
# also returns the final theta orientation of the node, as well as the total cost of the path
# path validity is not checked here
def generate_curve(x,y,theta,UL,UR):

    # robot parameters
    t = 0
    
    dt = 0.1
    cost=0


    # list of x and y values
    # will be set to the nodes local_path so we can graph it
    x_res = [x]
    y_res = [y]

    theta = 3.14 * theta / 180

    # generate the subpoints for the curve and
    # append the points to the x and y list
    while t<1:
        t = t + dt
        x += 0.5*r * (UL + UR) * math.cos(theta) * dt
        y += 0.5*r * (UL + UR) * math.sin(theta) * dt
        theta += (r / L) * (UR - UL) * dt
        cost = cost+ math.sqrt(math.pow((0.5*r * (UL + UR) * math.cos(theta) * dt),2)+math.pow((0.5*r * (UL + UR) * math.sin(theta) * dt),2))
        
        x_res.append(x)
        y_res.append(y)
        
    theta = 180 * (theta) / 3.14
    
    # retrun the x and ys to be plotted as well as the end theta, and cost of the curve 
    return x_res, y_res, theta, cost

# %%
# uses the predefined differential commands to generate the arc of the robots path
# for each point in the arc, check bounds and if in opstacle or margin, and disqualify arcs which contain invalid points
# if arc is valid then pull the node it ends on compare costs, and if cheaper, then update the cost and local path to the node

def gen_next_nodes(curr_node, color_map, board, goal_location, thresh):

    curr_y = curr_node.cell_location[0]
    curr_x = curr_node.cell_location[1]
    curr_angle = curr_node.cell_location[2]

    next_nodes = []

    actions=[[7, 3], [10, 0], [5, 5], [0,10], [3, 7]]
    for action in actions:

        x_res, y_res, theta, cost = generate_curve(curr_x, curr_y, curr_angle, action[0], action[1])

        valid = True

        # bounds checking
        for x in x_res:
            if int(x) < 0 or int(x) > 399:
                valid = False
        for y in y_res:
            if int(y) < 0 or int(y) > 249:
                valid = False


        if valid:
            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

        
        if valid:

            # use compressed coordinates to access a new node
            comp_x, comp_y, comp_angle = compress_coordinates(
                math.floor(x_res[-1]),
                math.floor(y_res[-1]),
                theta,
                thresh=thresh
            )

            c2c = curr_node.c2c + cost
            c2g = np.sqrt((x_res[-1]-goal_location[1])**2 + (y_res[-1]-goal_location[0])**2)
            h = c2g+c2c


            new_node = board[comp_y][comp_x][comp_angle]
            if h < new_node.h:
                new_node.parent = curr_node
                new_node.cell_location = [y_res[-1], x_res[-1], theta]
                new_node.c2c = c2c
                new_node.c2g = c2g
                new_node.h = h
                new_node.local_path = [x_res, y_res]
                new_node.command = action

            next_nodes.append(new_node)
                

    return next_nodes

# %%
# this is the backtracking function
# returns a list of nodes in order to find the solution
def get_solution_path(curr_node):
    solution_path= []
    
    while curr_node:
        solution_path.insert(0, curr_node)
        curr_node = curr_node.parent
        
    return solution_path

# %%
# get the command to get to each spot in the solution path
# the first element will always be 0 since we dont have to move to get there
def get_commands(solution_path):
    commands = list(node.command for node in solution_path)
    commands = list(filter(None, commands))
    return commands

# %%
# plot the chronologically ordered list of nodes in closed nodes, and then generate and plot the path for the solution

def animate(color_map, closed_nodes, solution_path):

    # draw explored nodes
    out = cv2.VideoWriter('test.avi',cv2.VideoWriter_fourcc(*'DIVX'), 60, (400, 250))
    for node in closed_nodes[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[255, 255, 255],1)        
                out.write(np.flipud(color_map))


    # draw the backtracked best path
    for node in solution_path[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[0, 0, 255],1)        
                out.write(np.flipud(color_map))

    out.release()

# %%
# make sure that the user defined paramters are fine
# not out of bounds and is a free space for start and goal

def validate_inputs(height, width, start_location, goal_location, color_map):
    if start_location[0] not in range(0, height) or start_location[1] not in range(0, width):
        print("Start Location Out Of Bounds")
        return False

    if goal_location[0] not in range(0, height) or goal_location[1] not in range(0, width):
        print("Goal Location Out Of Bounds")
        return False

    if color_map[start_location[0]][start_location[1]][0] == 255 or color_map[start_location[0]][start_location[1]][1] == 255:
        print('Cannot start in obstacle or obstacle margin')
        return False

    if color_map[goal_location[0]][goal_location[1]][0] == 255 or color_map[goal_location[0]][goal_location[1]][1] == 255:
        print('Cannot place goal in obstacle or obstacle margin')
        return False

    return True

# %%
# starting paramters
start_location = [0,0,0]
goal_location = [100,50,0]

# color map size
# board size will be based off of the color map and threshold
width = 200
height = 200

thresh = 1.5

print('Building Color Map')
color_map = create_color_map(height = height, width = width, radius=15, goal_location=goal_location)

print('Building Board')
board = create_board(width=width, height=height, thresh=thresh)

plt.figure(figsize=(10, 10))
plt.imshow(color_map, origin='lower')
# Out:
# Building Color Map
# Building Board

# %%
compressed_x_start, compressed_y_start, compressed_angle_start = compress_coordinates(
        start_location[1],
        start_location[0],
        start_location[2],
        thresh=thresh
    )

compressed_x_goal, compressed_y_goal, compressed_angle_goal = compress_coordinates(
    goal_location[1],
    goal_location[0],
    goal_location[2],
    thresh=thresh
)

print(f'Starting in region x: {compressed_x_start}, y: {compressed_y_start}, theta: {compressed_angle_start}')
print(f'Goal in region x: {compressed_x_goal}, y: {compressed_y_goal}, theta: {compressed_angle_goal}')
# Out:
# Starting in region x: 0, y: 0, theta: 0
# Goal in region x: 33, y: 66, theta: 0

# %%
start_node = board[compressed_y_start][compressed_x_start][compressed_angle_start]
goal_node = board[compressed_y_goal][compressed_x_goal][compressed_angle_goal]

start_node.c2c = 0
goal_region = goal_node.region

open_nodes = [start_node]
closed_nodes = []

found = False
solution_path = None
commands = None

print(f'Searching for goal region: {goal_region}')
while len(open_nodes) > 0:

    open_nodes.sort(key=lambda x: x.h)
    curr_node = open_nodes.pop(0)
    closed_nodes.append(curr_node)

    curr_x = curr_node.cell_location[1]
    curr_y = curr_node.cell_location[0]


    print(f"Current node has exact coordinates of x:{curr_x} y:{curr_y} Theta:{curr_node.cell_location[2]}")
    print(f"Current node is in region coordinates of {curr_node.region}")
    # print(f"Current node has coordinates of {curr_node.cell_location}")


    if int(color_map[int(curr_y)][int(curr_x)][0]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][1]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][2]) == 255:
        print('Found Solution')
        found = True

        print('Animating Search Pattern')          
        # back track and animate the search and solution
        solution_path = get_solution_path(curr_node)
        commands = get_commands(solution_path)
        animate(color_map, closed_nodes, solution_path)

        break

    else:
        next_possible_nodes = gen_next_nodes(
            curr_node=curr_node,
            board=board,
            goal_location=goal_location,
            color_map=color_map,
            thresh=thresh
        )
        
        for node in next_possible_nodes:

            appendable = True
            for o_node in open_nodes:
                if o_node.region == node.region:
                    appendable = False
                    break
            if appendable:
                for c_node in closed_nodes:
                    if c_node.region == node.region:
                        appendable = False
                        break

            if appendable:
                open_nodes.append(node)

if not found:
    print('No Solution')
# Out:
# Searching for goal region: [66, 33, 0]
# Current node has exact coordinates of x:0 y:0 Theta:0
# Current node is in region coordinates of [0, 0, 0]
# Current node has exact coordinates of x:3.0921750541591004 y:1.576280724879155 Theta:59.454049135577804
# Current node is in region coordinates of [0, 2, 5]
# Current node has exact coordinates of x:4.938691439267913 y:4.701545072022398 Theta:59.454049135577804
# Current node is in region coordinates of [2, 2, 5]
# Current node has exact coordinates of x:6.785207824376723 y:7.826809419165641 Theta:59.454049135577804
# Current node is in region coordinates of [4, 4, 5]
# Current node has exact coordinates of x:4.311394788475631 y:4.968041037301436 Theta:83.235668789809
# Current node is in region coordinates of [2, 2, 3]
# Current node has exact coordinates of x:8.631724209485533 y:10.952073766308875 Theta:59.454049135577804
# Current node is in region coordinates of [6, 5, 5]
# Current node has exact coordinates of x:6.157911173584445 y:8.09330538444468 Theta:83.235668789809
# Current node is in region coordinates of [5, 4, 3]
# Current node has exact coordinates of x:10.478240594594343 y:14.077338113452107 Theta:59.454049135577804
# Current node is in region coordinates of [9, 6, 5]
# Current node has exact coordinates of x:8.004427558693255 y:11.218569731587923 Theta:83.235668789809
# Current node is in region coordinates of [7, 5, 3]
# Current node has exact coordinates of x:12.324756979703153 y:17.20260246059534 Theta:59.454049135577804
# Current node is in region coordinates of [11, 8, 5]
# Current node has exact coordinates of x:9.85094394380206 y:14.343834078731156 Theta:83.235668789809
# Current node is in region coordinates of [9, 6, 3]
# Current node has exact coordinates of x:11.69746032891087 y:17.469098425874385 Theta:83.235668789809
# Current node is in region coordinates of [11, 7, 3]
# Current node has exact coordinates of x:5.401860041095318 y:8.403360572701143 Theta:59.454049135577804
# Current node is in region coordinates of [5, 3, 5]
# Current node has exact coordinates of x:14.171273364811963 y:20.327866807738573 Theta:59.454049135577804
# Current node is in region coordinates of [13, 9, 5]
# Current node has exact coordinates of x:7.248376426204132 y:11.528624919844384 Theta:59.454049135577804
# Current node is in region coordinates of [7, 4, 5]
# Current node has exact coordinates of x:13.54397671401968 y:20.59436277301762 Theta:83.235668789809
# Current node is in region coordinates of [13, 8, 3]
# Current node has exact coordinates of x:16.017789749920773 y:23.453131154881806 Theta:59.454049135577804
# Current node is in region coordinates of [15, 10, 5]
# Current node has exact coordinates of x:15.39049309912849 y:23.719627120160855 Theta:83.235668789809
# Current node is in region coordinates of [15, 10, 3]
# Current node has exact coordinates of x:10.941409196421741 y:17.779153614130863 Theta:59.454049135577804
# Current node is in region coordinates of [11, 6, 5]
# Current node has exact coordinates of x:6.62107977541185 y:11.795120885123424 Theta:83.235668789809
# Current node is in region coordinates of [7, 4, 3]
# Current node has exact coordinates of x:17.864306135029583 y:26.57839550202504 Theta:59.454049135577804
# Current node is in region coordinates of [17, 11, 5]
# Current node has exact coordinates of x:12.787925581530551 y:20.904417961274092 Theta:59.454049135577804
# Current node is in region coordinates of [13, 8, 5]
# Current node has exact coordinates of x:8.46759616052066 y:14.920385232266668 Theta:83.235668789809
# Current node is in region coordinates of [9, 5, 3]
# Current node has exact coordinates of x:17.2370094842373 y:26.844891467304087 Theta:83.235668789809
# Current node is in region coordinates of [17, 11, 3]
# Current node has exact coordinates of x:5.474777530584159 y:4.280673487922817 Theta:35.6724294813467
# Current node is in region coordinates of [2, 3, 9]
# Current node has exact coordinates of x:14.634441966639361 y:24.02968230841733 Theta:59.454049135577804
# Current node is in region coordinates of [16, 9, 5]
# Current node has exact coordinates of x:19.710822520138393 y:29.70365984916827 Theta:59.454049135577804
# Current node is in region coordinates of [19, 12, 5]
# Current node has exact coordinates of x:7.321293915692971 y:7.4059378350660605 Theta:35.6724294813467
# Current node is in region coordinates of [4, 4, 9]
# Current node has exact coordinates of x:12.160628930738268 y:21.170913926553144 Theta:83.235668789809
# Current node is in region coordinates of [14, 8, 3]
# Current node has exact coordinates of x:19.08352586934611 y:29.97015581444732 Theta:83.235668789809
# Current node is in region coordinates of [19, 12, 3]
# Current node has exact coordinates of x:16.48095835174817 y:27.15494665556056 Theta:59.454049135577804
# Current node is in region coordinates of [18, 10, 5]
# Current node has exact coordinates of x:14.007145315847078 y:24.296178273696373 Theta:83.235668789809
# Current node is in region coordinates of [16, 9, 3]
# Current node has exact coordinates of x:9.167810300801781 y:10.5312021822093 Theta:35.6724294813467
# Current node is in region coordinates of [6, 6, 9]
# Current node has exact coordinates of x:18.327474736856985 y:30.280211002703794 Theta:59.454049135577804
# Current node is in region coordinates of [20, 12, 5]
# Current node has exact coordinates of x:15.853661700955888 y:27.42144262083961 Theta:83.235668789809
# Current node is in region coordinates of [18, 10, 3]
# Current node has exact coordinates of x:7.711545028031537 y:15.230440420523129 Theta:59.454049135577804
# Current node is in region coordinates of [10, 4, 5]
# Current node has exact coordinates of x:11.014326685910593 y:13.656466529352533 Theta:35.6724294813467
# Current node is in region coordinates of [8, 7, 9]
# Current node has exact coordinates of x:9.558061413140342 y:18.355704767666374 Theta:59.454049135577804
# Current node is in region coordinates of [12, 6, 5]
# Current node has exact coordinates of x:17.7001780860647 y:30.546706967982843 Theta:83.235668789809
# Current node is in region coordinates of [20, 11, 3]
# Current node has exact coordinates of x:6.243041535692678 y:7.851606249526605 Theta:23.78161965423118
# Current node is in region coordinates of [4, 4, 2]
# Current node has exact coordinates of x:11.404577798249152 y:21.480969114809607 Theta:59.454049135577804
# Current node is in region coordinates of [14, 7, 5]
# Current node has exact coordinates of x:4.741611874919148 y:8.572456837196345 Theta:83.235668789809
# Current node is in region coordinates of [5, 2, 3]
# Current node has exact coordinates of x:12.860843071019403 y:16.781730876495768 Theta:35.6724294813467
# Current node is in region coordinates of [10, 8, 9]
# Current node has exact coordinates of x:13.25109418335795 y:24.60623346195285 Theta:59.454049135577804
# Current node is in region coordinates of [16, 8, 5]
# Current node has exact coordinates of x:19.546694471173513 y:33.671971315126065 Theta:83.235668789809
# Current node is in region coordinates of [22, 12, 3]
# Current node has exact coordinates of x:8.089557920801491 y:10.976870596669851 Theta:23.78161965423118
# Current node is in region coordinates of [6, 5, 2]
# Current node has exact coordinates of x:7.784462517520376 y:11.107753335744802 Theta:35.6724294813467
# Current node is in region coordinates of [7, 4, 9]
# Current node has exact coordinates of x:9.936074305910303 y:14.102134943813095 Theta:23.78161965423118
# Current node is in region coordinates of [9, 6, 2]
# Current node has exact coordinates of x:8.930764762348064 y:18.622200732945416 Theta:83.235668789809
# Current node is in region coordinates of [12, 5, 3]
# Current node has exact coordinates of x:14.707359456128213 y:19.906995223639004 Theta:35.6724294813467
# Current node is in region coordinates of [12, 9, 9]
# Current node has exact coordinates of x:16.94412695357557 y:30.856762156239316 Theta:59.454049135577804
# Current node is in region coordinates of [20, 10, 5]
# Current node has exact coordinates of x:10.281161030245576 y:17.948249878626065 Theta:83.235668789809
# Current node is in region coordinates of [11, 6, 3]
# Current node has exact coordinates of x:10.777281147456868 y:21.747465080088656 Theta:83.235668789809
# Current node is in region coordinates of [14, 6, 3]
# Current node has exact coordinates of x:9.630978902629192 y:14.233017682888045 Theta:35.6724294813467
# Current node is in region coordinates of [9, 6, 9]
# Current node has exact coordinates of x:11.782590691019108 y:17.227399290956328 Theta:23.78161965423118
# Current node is in region coordinates of [11, 7, 2]
# Current node has exact coordinates of x:12.623797532565678 y:24.87272942723189 Theta:83.235668789809
# Current node is in region coordinates of [16, 8, 3]
# Current node has exact coordinates of x:18.79064333868438 y:33.98202650338257 Theta:59.454049135577804
# Current node is in region coordinates of [22, 12, 5]
# Current node has exact coordinates of x:16.553875841237026 y:23.032259570782237 Theta:35.6724294813467
# Current node is in region coordinates of [15, 10, 9]
# Current node has exact coordinates of x:14.470313917674476 y:27.997993774375132 Theta:83.235668789809
# Current node is in region coordinates of [18, 9, 3]
# Current node has exact coordinates of x:13.629107076127918 y:20.35266363809955 Theta:23.78161965423118
# Current node is in region coordinates of [13, 8, 2]
# Current node has exact coordinates of x:5.832077127538835 y:12.00777637259605 Theta:59.454049135577804
# Current node is in region coordinates of [8, 3, 5]
# Current node has exact coordinates of x:13.324011672846801 y:20.483546377174527 Theta:35.6724294813467
# Current node is in region coordinates of [13, 8, 9]
# Current node has exact coordinates of x:18.400392226345833 y:26.15752391792547 Theta:35.6724294813467
# Current node is in region coordinates of [17, 12, 9]
# Current node has exact coordinates of x:15.475623461236728 y:23.477927985242786 Theta:23.78161965423118
# Current node is in region coordinates of [15, 10, 2]
# Current node has exact coordinates of x:8.552726522628896 y:14.678686097348596 Theta:23.78161965423118
# Current node is in region coordinates of [9, 5, 2]
# Current node has exact coordinates of x:10.021230014967745 y:22.057520268345122 Theta:59.454049135577804
# Current node is in region coordinates of [14, 6, 5]
# Current node has exact coordinates of x:17.322139846345536 y:26.603192332386023 Theta:23.78161965423118
# Current node is in region coordinates of [17, 11, 2]
# Current node has exact coordinates of x:11.867746400076555 y:25.182784615488355 Theta:59.454049135577804
# Current node is in region coordinates of [16, 7, 5]
# Current node has exact coordinates of x:17.017044443064425 y:26.734075071460992 Theta:35.6724294813467
# Current node is in region coordinates of [17, 11, 9]
# Current node has exact coordinates of x:10.399242907737708 y:17.803950444491836 Theta:23.78161965423118
# Current node is in region coordinates of [11, 6, 2]
# Current node has exact coordinates of x:20.246908611454643 y:29.282788265068703 Theta:35.6724294813467
# Current node is in region coordinates of [19, 13, 9]
# Current node has exact coordinates of x:13.714262785185365 y:28.308048962631588 Theta:59.454049135577804
# Current node is in region coordinates of [18, 8, 5]
# Current node has exact coordinates of x:7.051296861855366 y:15.399536685018333 Theta:83.235668789809
# Current node is in region coordinates of [10, 4, 3]
# Current node has exact coordinates of x:10.761547260131548 y:13.614416413114395 Theta:95.12647861692452
# Current node is in region coordinates of [8, 6, 2]
# Current node has exact coordinates of x:10.094147504456597 y:17.93483318356679 Theta:35.6724294813467
# Current node is in region coordinates of [11, 6, 9]
# Current node has exact coordinates of x:19.168656231454346 y:29.728456679529252 Theta:23.78161965423118
# Current node is in region coordinates of [19, 12, 2]
# Current node has exact coordinates of x:18.86356082817323 y:29.859339418604225 Theta:35.6724294813467
# Current node is in region coordinates of [19, 12, 9]
# Current node has exact coordinates of x:11.940663889565402 y:21.06009753071004 Theta:35.6724294813467
# Current node is in region coordinates of [14, 7, 9]
# Current node has exact coordinates of x:14.092275677955316 y:24.054479138778312 Theta:23.78161965423118
# Current node is in region coordinates of [16, 9, 2]
# Current node has exact coordinates of x:12.60806364524036 y:16.739680760257627 Theta:95.12647861692452
# Current node is in region coordinates of [10, 8, 2]
# Current node has exact coordinates of x:13.787180274674212 y:24.18536187785327 Theta:35.6724294813467
# Current node is in region coordinates of [16, 8, 9]
# Current node has exact coordinates of x:15.938792063064126 y:27.17974348592154 Theta:23.78161965423118
# Current node is in region coordinates of [18, 10, 2]
# Current node has exact coordinates of x:11.240449749284272 y:25.449280580767404 Theta:83.235668789809
# Current node is in region coordinates of [16, 7, 3]
# Current node has exact coordinates of x:13.086966134393082 y:28.574544927910637 Theta:83.235668789809
# Current node is in region coordinates of [18, 8, 3]
# Current node has exact coordinates of x:9.804172189162069 y:10.018570655920316 Theta:59.454049135577804
# Current node is in region coordinates of [6, 6, 5]
# Current node has exact coordinates of x:16.283878787399406 y:31.02585842073452 Theta:83.235668789809
# Current node is in region coordinates of [20, 10, 3]
# Current node has exact coordinates of x:15.63369665978301 y:27.310626224996515 Theta:35.6724294813467
# Current node is in region coordinates of [18, 10, 9]
# Current node has exact coordinates of x:14.45458003034917 y:19.864945107400867 Theta:95.12647861692452
# Current node is in region coordinates of [12, 9, 2]
# Current node has exact coordinates of x:14.933482519501892 y:31.69980927505387 Theta:83.235668789809
# Current node is in region coordinates of [20, 9, 3]
# Current node has exact coordinates of x:3.3080036912322646 y:5.040328283531972 Theta:118.90809827115561
# Current node is in region coordinates of [3, 2, 2]
# Current node has exact coordinates of x:17.785308448172934 y:30.305007833064778 Theta:23.78161965423118
# Current node is in region coordinates of [20, 11, 2]
# Current node has exact coordinates of x:5.154520076341077 y:8.165592630675215 Theta:118.90809827115561
# Current node is in region coordinates of [5, 3, 2]
# Current node has exact coordinates of x:11.650688574270879 y:13.143835003063556 Theta:59.454049135577804
# Current node is in region coordinates of [8, 7, 5]
# Current node has exact coordinates of x:6.673258622136194 y:11.456022049421517 Theta:23.78161965423118
# Current node is in region coordinates of [7, 4, 2]
# Current node has exact coordinates of x:19.631824833281744 y:33.430272180208014 Theta:23.78161965423118
# Current node is in region coordinates of [22, 12, 2]
# Current node has exact coordinates of x:16.301096415457984 y:22.990209454544104 Theta:95.12647861692452
# Current node is in region coordinates of [14, 10, 2]
# Current node has exact coordinates of x:8.141762114475053 y:18.83485622041804 Theta:59.454049135577804
# Current node is in region coordinates of [12, 5, 5]
# Current node has exact coordinates of x:11.023391923478595 y:13.410330968342599 Theta:83.235668789809
# Current node is in region coordinates of [8, 7, 3]
# Current node has exact coordinates of x:19.32672943000063 y:33.56115491928298 Theta:35.6724294813467
# Current node is in region coordinates of [22, 12, 9]
# Current node has exact coordinates of x:10.862411509565112 y:21.50576594517058 Theta:23.78161965423118
# Current node is in region coordinates of [14, 6, 2]
# Current node has exact coordinates of x:13.49720495937969 y:16.26909935020679 Theta:59.454049135577804
# Current node is in region coordinates of [10, 8, 5]
# Current node has exact coordinates of x:5.171828961362664 y:12.176872637091254 Theta:83.235668789809
# Current node is in region coordinates of [8, 3, 3]
# Current node has exact coordinates of x:8.214679603963893 y:14.71216913563971 Theta:35.6724294813467
# Current node is in region coordinates of [9, 5, 9]
# Current node has exact coordinates of x:18.147612800566794 y:26.115473801687333 Theta:95.12647861692452
# Current node is in region coordinates of [17, 12, 2]
# Current node has exact coordinates of x:12.708927894673916 y:24.631030292313824 Theta:23.78161965423118
# Current node is in region coordinates of [16, 8, 2]
# Current node has exact coordinates of x:12.869908308587405 y:16.53559531548584 Theta:83.235668789809
# Current node is in region coordinates of [10, 8, 3]
# Current node has exact coordinates of x:10.267340790989474 y:13.720386156599057 Theta:59.454049135577804
# Current node is in region coordinates of [8, 6, 5]
# Current node has exact coordinates of x:14.917748632176568 y:23.566760608079623 Theta:95.12647861692452
# Current node is in region coordinates of [15, 9, 2]
# Current node has exact coordinates of x:14.555444279782726 y:27.756294639457053 Theta:23.78161965423118
# Current node is in region coordinates of [18, 9, 2]
# Current node has exact coordinates of x:17.37434404001909 y:34.46117795613422 Theta:59.454049135577804
# Current node is in region coordinates of [22, 11, 5]
# Current node has exact coordinates of x:14.177431387012764 y:32.00986446331034 Theta:59.454049135577804
# Current node is in region coordinates of [21, 9, 5]
# Current node has exact coordinates of x:15.3437213444885 y:19.394363697350027 Theta:59.454049135577804
# Current node is in region coordinates of [12, 10, 5]
# Current node has exact coordinates of x:16.401960664891526 y:30.881558986600297 Theta:23.78161965423118
# Current node is in region coordinates of [20, 10, 2]
# Current node has exact coordinates of x:16.023947772121574 y:35.135128810453615 Theta:59.454049135577804
# Current node is in region coordinates of [23, 10, 5]
# Current node has exact coordinates of x:14.716424693696217 y:19.660859662629072 Theta:83.235668789809
# Current node is in region coordinates of [12, 9, 3]
# Current node has exact coordinates of x:14.250348876501615 y:27.88717737853202 Theta:35.6724294813467
# Current node is in region coordinates of [18, 9, 9]
# Current node has exact coordinates of x:17.870464157230384 y:38.26039315759689 Theta:59.454049135577804
# Current node is in region coordinates of [25, 11, 5]
# Current node has exact coordinates of x:8.437585028894528 y:10.540506832596723 Theta:83.235668789809
# Current node is in region coordinates of [6, 5, 3]
# Current node has exact coordinates of x:16.096865261610425 y:31.012441725675252 Theta:35.6724294813467
# Current node is in region coordinates of [20, 10, 9]
# Current node has exact coordinates of x:16.233618386993935 y:26.917178713534618 Theta:118.90809827115561
# Current node is in region coordinates of [17, 10, 2]
# Current node has exact coordinates of x:13.960373561207087 y:19.970914850885546 Theta:59.454049135577804
# Current node is in region coordinates of [12, 8, 5]
# Current node has exact coordinates of x:17.190237729597307 y:22.519628044493263 Theta:59.454049135577804
# Current node is in region coordinates of [14, 11, 5]
# Current node has exact coordinates of x:10.28410141400334 y:13.66577117973997 Theta:83.235668789809
# Current node is in region coordinates of [8, 6, 3]
# Current node has exact coordinates of x:16.56294107880503 y:22.78612400977231 Theta:83.235668789809
# Current node is in region coordinates of [14, 10, 3]
# Current node has exact coordinates of x:18.593563774335617 y:37.8529382685565 Theta:83.235668789809
# Current node is in region coordinates of [24, 12, 3]
# Current node has exact coordinates of x:11.687884463786364 y:21.01804741447189 Theta:95.12647861692452
# Current node is in region coordinates of [14, 7, 2]
# Current node has exact coordinates of x:18.080134772102745 y:30.04244306067785 Theta:118.90809827115561
# Current node is in region coordinates of [20, 12, 2]
# Current node has exact coordinates of x:5.6176886781684825 y:11.867408131353956 Theta:118.90809827115561
# Current node is in region coordinates of [7, 3, 2]
# Current node has exact coordinates of x:7.464205063277296 y:14.9926724784972 Theta:118.90809827115561
# Current node is in region coordinates of [9, 4, 2]
# Current node has exact coordinates of x:18.409457463913835 y:25.911388356915545 Theta:83.235668789809
# Current node is in region coordinates of [16, 12, 3]
# Current node has exact coordinates of x:15.39665112132929 y:35.40162477573262 Theta:83.235668789809
# Current node is in region coordinates of [23, 10, 3]
# Current node has exact coordinates of x:13.904449320474228 y:19.95924465467529 Theta:35.67242948134671
# Current node is in region coordinates of [12, 8, 9]
# Current node has exact coordinates of x:8.982943609072413 y:18.283101897243498 Theta:23.78161965423118
# Current node is in region coordinates of [12, 5, 2]
# Current node has exact coordinates of x:19.036754114706124 y:25.644892391636496 Theta:59.454049135577804
# Current node is in region coordinates of [16, 12, 5]
# Current node has exact coordinates of x:17.243167506438102 y:38.52688912287589 Theta:83.235668789809
# Current node is in region coordinates of [25, 11, 3]
# Current node has exact coordinates of x:4.060112697126127 y:8.563509308338851 Theta:107.01728844404016
# Current node is in region coordinates of [5, 2, 2]
# Current node has exact coordinates of x:13.977134184220956 y:19.916299874026443 Theta:83.235668789809
# Current node is in region coordinates of [12, 8, 3]
# Current node has exact coordinates of x:11.374566666623021 y:17.101090715139673 Theta:59.454049135577804
# Current node is in region coordinates of [11, 7, 5]
# Current node has exact coordinates of x:10.524364590900113 y:21.539248983461704 Theta:35.6724294813467
# Current node is in region coordinates of [14, 6, 9]
# Current node has exact coordinates of x:20.255973849022652 y:29.036652704058778 Theta:83.235668789809
# Current node is in region coordinates of [19, 13, 3]
# Current node has exact coordinates of x:13.17209649650132 y:28.332845792992572 Theta:23.78161965423118
# Current node is in region coordinates of [18, 8, 2]
# Current node has exact coordinates of x:20.88327049981493 y:28.77015673877973 Theta:59.454049135577804
# Current node is in region coordinates of [18, 13, 5]
# Current node has exact coordinates of x:14.423542163034499 y:23.672730351564297 Theta:59.454049135577804
# Current node is in region coordinates of [15, 9, 5]
# Current node has exact coordinates of x:11.121152597441093 y:17.200670556206905 Theta:71.34485896269334
# Current node is in region coordinates of [11, 7, 4]
# Current node has exact coordinates of x:7.481513948298883 y:19.003952484913242 Theta:83.235668789809
# Current node is in region coordinates of [12, 4, 3]
# Current node has exact coordinates of x:16.86512926671894 y:34.58337448727904 Theta:23.78161965423118
# Current node is in region coordinates of [22, 10, 2]
# Current node has exact coordinates of x:12.186774665587128 y:12.722963418963976 Theta:35.6724294813467
# Current node is in region coordinates of [8, 8, 9]
# Current node has exact coordinates of x:16.27005854814331 y:26.79799469870753 Theta:59.454049135577804
# Current node is in region coordinates of [17, 10, 5]
# Current node has exact coordinates of x:12.967668982549904 y:20.325934903350145 Theta:71.34485896269334
# Current node is in region coordinates of [13, 8, 4]
# Current node has exact coordinates of x:16.560033863437827 y:34.71425722635401 Theta:35.6724294813467
# Current node is in region coordinates of [22, 10, 9]
# Current node has exact coordinates of x:3.5403462244992476 y:0.6756355438723463 Theta:23.78161965423112
# Current node is in region coordinates of [0, 2, 2]
# Current node has exact coordinates of x:16.714095873842922 y:34.63027422062943 Theta:83.235668789809
# Current node is in region coordinates of [22, 10, 3]
# Current node has exact coordinates of x:14.814185367658714 y:23.451199250493385 Theta:71.34485896269334
# Current node is in region coordinates of [15, 9, 4]
# Current node has exact coordinates of x:18.406550248546633 y:37.83952157349728 Theta:35.6724294813467
# Current node is in region coordinates of [24, 12, 9]
# Current node has exact coordinates of x:12.8957267292456 y:20.337774543676883 Theta:47.56323930846219
# Current node is in region coordinates of [13, 8, 6]
# Current node has exact coordinates of x:14.033291050695938 y:15.848227766107216 Theta:35.6724294813467
# Current node is in region coordinates of [10, 9, 9]
# Current node has exact coordinates of x:16.48711637394897 y:38.83694431113232 Theta:59.454049135577804
# Current node is in region coordinates of [25, 10, 5]
# Current node has exact coordinates of x:16.214134307410436 y:26.78632450249729 Theta:35.67242948134671
# Current node is in region coordinates of [17, 10, 9]
# Current node has exact coordinates of x:18.333632759057785 y:41.96220865827559 Theta:59.454049135577804
# Current node is in region coordinates of [27, 12, 5]
# Current node has exact coordinates of x:7.10347570857971 y:15.060437849316425 Theta:23.78161965423118
# Current node is in region coordinates of [10, 4, 2]
# Current node has exact coordinates of x:14.742243114354412 y:23.463038890820123 Theta:47.56323930846219
# Current node is in region coordinates of [15, 9, 6]
# Current node has exact coordinates of x:11.670666835727788 y:29.053696380662313 Theta:83.235668789809
# Current node is in region coordinates of [19, 7, 3]
# Current node has exact coordinates of x:16.66070175276753 y:26.57646359763662 Theta:71.34485896269334
# Current node is in region coordinates of [17, 10, 4]
# Current node has exact coordinates of x:13.517183220836598 y:32.178960727805546 Theta:83.235668789809
# Current node is in region coordinates of [21, 8, 3]
# Current node has exact coordinates of x:8.424327683177394 y:6.396578470982601 Theta:35.6724294813467
# Current node is in region coordinates of [4, 5, 9]
# Current node has exact coordinates of x:16.286819171157163 y:26.743379721848427 Theta:83.235668789809
# Current node is in region coordinates of [17, 10, 3]
# Current node has exact coordinates of x:7.9273736651046995 y:18.69448797917594 Theta:118.90809827115561
# Current node is in region coordinates of [12, 4, 2]
# Current node has exact coordinates of x:17.824005390598252 y:30.015013385877264 Theta:71.34485896269334
# Current node is in region coordinates of [20, 11, 4]
# Current node has exact coordinates of x:16.588759499463222 y:26.588303237963363 Theta:47.56323930846219
# Current node is in region coordinates of [17, 10, 6]
# Current node has exact coordinates of x:15.87980743580475 y:18.973492113250455 Theta:35.6724294813467
# Current node is in region coordinates of [12, 10, 9]
# Current node has exact coordinates of x:17.690602220940193 y:34.095655956580345 Theta:95.12647861692452
# Current node is in region coordinates of [22, 11, 2]
# Current node has exact coordinates of x:18.50721813787634 y:29.70172794477985 Theta:71.34485896269334
# Current node is in region coordinates of [19, 12, 4]
# Current node has exact coordinates of x:11.620406435322314 y:24.94501667346242 Theta:118.90809827115561
# Current node is in region coordinates of [16, 7, 2]
# Current node has exact coordinates of x:8.571979200918568 y:22.43927202031295 Theta:59.454049135577804
# Current node is in region coordinates of [14, 5, 5]
# Current node has exact coordinates of x:10.418495586027378 y:25.56453636745618 Theta:59.454049135577804
# Current node is in region coordinates of [16, 6, 5]
# Current node has exact coordinates of x:19.670521775707062 y:33.1402777330205 Theta:71.34485896269334
# Current node is in region coordinates of [22, 12, 4]
# Current node has exact coordinates of x:18.435275884572036 y:29.7135675851066 Theta:47.56323930846219
# Current node is in region coordinates of [19, 12, 6]
# Current node has exact coordinates of x:19.97985194137478 y:32.993908416134886 Theta:83.235668789809
# Current node is in region coordinates of [21, 12, 3]
# Current node has exact coordinates of x:5.60204604780618 y:15.781288436986163 Theta:83.235668789809
# Current node is in region coordinates of [10, 3, 3]
# Current node has exact coordinates of x:17.72632382091356 y:22.09875646039369 Theta:35.6724294813467
# Current node is in region coordinates of [14, 11, 9]
# Current node has exact coordinates of x:6.0222152342371835 y:3.436676390407696 Theta:0.0
# Current node is in region coordinates of [2, 4, 0]
# Current node has exact coordinates of x:19.59857952240276 y:33.15211737334724 Theta:47.56323930846219
# Current node is in region coordinates of [22, 12, 6]
# Current node has exact coordinates of x:17.377284423776846 y:30.178699257248134 Theta:59.454049135577804
# Current node is in region coordinates of [20, 11, 5]
# Current node has exact coordinates of x:15.277353969486112 y:27.15301475117214 Theta:71.34485896269334
# Current node is in region coordinates of [18, 10, 4]
# Current node has exact coordinates of x:16.34297603763215 y:22.67530761392921 Theta:35.6724294813467
# Current node is in region coordinates of [14, 10, 9]
# Current node has exact coordinates of x:17.7063361082655 y:42.2287046235546 Theta:83.235668789809
# Current node is in region coordinates of [28, 11, 3]
# Current node has exact coordinates of x:7.868731619345995 y:6.561940737550939 Theta:0.0
# Current node is in region coordinates of [4, 4, 0]
# Current node has exact coordinates of x:17.328297868546336 y:38.28518998795779 Theta:23.78161965423118
# Current node is in region coordinates of [25, 11, 2]
# Current node has exact coordinates of x:16.440657607316837 y:30.591564539412783 Theta:71.34485896269334
# Current node is in region coordinates of [20, 10, 4]
# Current node has exact coordinates of x:14.407351270664472 y:23.52071567392135 Theta:83.235668789809
# Current node is in region coordinates of [15, 9, 3]
# Current node has exact coordinates of x:10.734012670113602 y:13.223658318804596 Theta:35.6724294813467
# Current node is in region coordinates of [8, 6, 9]
# Current node has exact coordinates of x:19.572840206022367 y:25.224020807536927 Theta:35.6724294813467
# Current node is in region coordinates of [16, 12, 9]
# Current node has exact coordinates of x:12.76113208834747 y:32.48901591606202 Theta:59.454049135577804
# Current node is in region coordinates of [21, 8, 5]
# Current node has exact coordinates of x:18.494587826022073 y:25.669689221997473 Theta:23.78161965423118
# Current node is in region coordinates of [16, 12, 2]
# Current node has exact coordinates of x:14.60764847345628 y:35.614280263205295 Theta:59.454049135577804
# Current node is in region coordinates of [23, 9, 5]
# Current node has exact coordinates of x:17.05192810129062 y:30.290118738642118 Theta:47.56323930846219
# Current node is in region coordinates of [20, 11, 6]
# Current node has exact coordinates of x:9.791198935235094 y:25.83103233273523 Theta:83.235668789809
# Current node is in region coordinates of [16, 6, 3]
# Current node has exact coordinates of x:11.637715320343904 y:28.956296679878463 Theta:83.235668789809
# Current node is in region coordinates of [18, 7, 3]
# Current node has exact coordinates of x:9.715248004454807 y:9.68720508469418 Theta:0.0
# Current node is in region coordinates of [6, 6, 0]
# Current node has exact coordinates of x:17.60396124514756 y:34.03011432765343 Theta:71.34485896269334
# Current node is in region coordinates of [22, 11, 4]
# Current node has exact coordinates of x:9.210752913047148 y:9.896899372330916 Theta:47.56323930846229
# Current node is in region coordinates of [6, 6, 6]
# Current node has exact coordinates of x:11.561764389563617 y:12.812469431837412 Theta:0.0
# Current node is in region coordinates of [8, 7, 0]
# Current node has exact coordinates of x:20.34110421113088 y:28.79495356914071 Theta:23.78161965423118
# Current node is in region coordinates of [18, 13, 2]
# Current node has exact coordinates of x:6.692511300425867 y:19.21660797238587 Theta:59.454049135577804
# Current node is in region coordinates of [12, 4, 5]
# Current node has exact coordinates of x:21.419356591131184 y:28.34928515468016 Theta:35.6724294813467
# Current node is in region coordinates of [18, 14, 9]
# Current node has exact coordinates of x:18.153770822767594 y:37.79747145725911 Theta:95.12647861692452
# Current node is in region coordinates of [24, 12, 2]
# Current node has exact coordinates of x:4.490329783569643 y:12.167925108233758 Theta:107.01728844404016
# Current node is in region coordinates of [8, 2, 2]
# Current node has exact coordinates of x:11.615723172049945 y:20.77081547262148 Theta:95.12647861692452
# Current node is in region coordinates of [13, 7, 2]
# Current node has exact coordinates of x:11.057269298155962 y:13.022163719474163 Theta:47.56323930846229
# Current node is in region coordinates of [8, 7, 6]
# Current node has exact coordinates of x:12.047489801095908 y:24.60430155756441 Theta:71.34485896269334
# Current node is in region coordinates of [16, 8, 4]
# Current node has exact coordinates of x:16.387327593943326 y:22.57187747552955 Theta:59.45404913557782
# Current node is in region coordinates of [14, 10, 5]
# Current node has exact coordinates of x:18.76726488297828 y:37.46866411589407 Theta:71.34485896269334
# Current node is in region coordinates of [24, 12, 4]
# Current node has exact coordinates of x:8.331900221173402 y:10.26375623822968 Theta:0.0
# Current node is in region coordinates of [6, 5, 0]
# Current node has exact coordinates of x:11.177487102274261 y:20.972002480313613 Theta:83.235668789809
# Current node is in region coordinates of [13, 7, 3]
# Current node has exact coordinates of x:13.462239557158757 y:23.89607981976472 Theta:95.12647861692452
# Current node is in region coordinates of [15, 8, 2]
# Current node has exact coordinates of x:13.408280774672427 y:15.937733778980645 Theta:0.0
# Current node is in region coordinates of [10, 8, 0]
# Current node has exact coordinates of x:15.346290978552712 y:23.015765368907246 Theta:47.56323930846219
# Current node is in region coordinates of [15, 10, 6]
# Current node has exact coordinates of x:15.627028010025706 y:18.931441997012318 Theta:95.12647861692452
# Current node is in region coordinates of [12, 10, 2]
# Current node has exact coordinates of x:17.807871266740204 y:29.86953873340239 Theta:95.12647861692452
# Current node is in region coordinates of [19, 11, 2]
# Current node has exact coordinates of x:10.954581677343628 y:25.143664783356613 Theta:35.6724294813467
# Current node is in region coordinates of [16, 6, 9]
# Current node has exact coordinates of x:10.237058652040908 y:25.521567826997934 Theta:118.90809827115561
# Current node is in region coordinates of [16, 6, 2]
# Current node has exact coordinates of x:12.903785683264774 y:16.147428066617408 Theta:47.56323930846229
# Current node is in region coordinates of [10, 8, 6]
# Current node has exact coordinates of x:12.801098062452438 y:28.268929130499846 Theta:35.6724294813467
# Current node is in region coordinates of [18, 8, 9]
# Current node has exact coordinates of x:13.980351822663996 y:35.8807762284843 Theta:83.235668789809
# Current node is in region coordinates of [23, 8, 3]
# Current node has exact coordinates of x:15.826868207772806 y:39.00604057562757 Theta:83.235668789809
# Current node is in region coordinates of [26, 10, 3]
# Current node has exact coordinates of x:13.930091422258528 y:31.7720965212844 Theta:118.90809827115561
# Current node is in region coordinates of [20, 8, 2]
# Current node has exact coordinates of x:10.018064642507161 y:9.479792701887696 Theta:95.12647861692452
# Current node is in region coordinates of [6, 6, 2]
# Current node has exact coordinates of x:10.178416606282216 y:13.389020585372924 Theta:0.0
# Current node is in region coordinates of [8, 6, 0]
# Current node has exact coordinates of x:11.866517211344041 y:16.60788256171637 Theta:118.90809827115561
# Current node is in region coordinates of [10, 7, 2]
# Current node has exact coordinates of x:18.796801360885183 y:45.6640241589543 Theta:59.454049135577804
# Current node is in region coordinates of [30, 12, 5]
# Current node has exact coordinates of x:13.822063932900416 y:27.741405545034386 Theta:47.56323930846219
# Current node is in region coordinates of [18, 8, 6]
# Current node has exact coordinates of x:11.102350736804052 y:12.964861635890866 Theta:71.34485896269345
# Current node is in region coordinates of [8, 7, 4]
# Current node has exact coordinates of x:17.606547328259854 y:25.963637787951832 Theta:83.23566878980901
# Current node is in region coordinates of [16, 11, 3]
# Current node has exact coordinates of x:13.21079343892663 y:28.04285134580505 Theta:71.34485896269334
# Current node is in region coordinates of [18, 8, 4]
# Current node has exact coordinates of x:8.679482670998558 y:22.217669003982827 Theta:107.01728844404016
# Current node is in region coordinates of [14, 5, 2]
# Current node has exact coordinates of x:15.448829968053646 y:35.06252594003072 Theta:23.78161965423118
# Current node is in region coordinates of [23, 10, 2]
# Current node has exact coordinates of x:17.192807363661515 y:26.141029716050486 Theta:47.56323930846219
# Current node is in region coordinates of [17, 11, 6]
# Current node has exact coordinates of x:15.254797159781237 y:19.06299812612388 Theta:0.0
# Current node is in region coordinates of [12, 10, 0]
# Current node has exact coordinates of x:14.750302068373578 y:19.272692413760634 Theta:47.56323930846229
# Current node is in region coordinates of [12, 9, 6]
# Current node has exact coordinates of x:17.473544395134518 y:22.056706344155554 Theta:95.12647861692452
# Current node is in region coordinates of [14, 11, 2]
# Current node has exact coordinates of x:13.713033596452853 y:19.733146908859602 Theta:118.90809827115561
# Current node is in region coordinates of [12, 8, 2]
# Current node has exact coordinates of x:12.265654374634774 y:16.40341142413151 Theta:71.34485896269345
# Current node is in region coordinates of [10, 8, 4]
# Current node has exact coordinates of x:14.21903182632497 y:31.593462045412544 Theta:107.01728844404016
# Current node is in region coordinates of [20, 9, 2]
# Current node has exact coordinates of x:10.881664187854776 y:29.266351868134937 Theta:59.454049135577804
# Current node is in region coordinates of [19, 6, 5]
# Current node has exact coordinates of x:7.911731034742399 y:22.60836828480815 Theta:83.235668789809
# Current node is in region coordinates of [14, 4, 3]
# Current node has exact coordinates of x:14.890214042158627 y:23.176002513769813 Theta:35.6724294813467
# Current node is in region coordinates of [15, 9, 9]
# Current node has exact coordinates of x:14.985367570731139 y:31.17995533327503 Theta:47.56323930846219
# Current node is in region coordinates of [20, 9, 6]
# Current node has exact coordinates of x:15.14373456477253 y:35.19340867910569 Theta:35.6724294813467
# Current node is in region coordinates of [23, 10, 9]
# Current node has exact coordinates of x:11.520437899983367 y:16.723979220152906 Theta:47.56323930846229
# Current node is in region coordinates of [10, 7, 6]
# Current node has exact coordinates of x:13.428958012465497 y:19.84196121237215 Theta:71.34485896269345
# Current node is in region coordinates of [12, 8, 4]
# Current node has exact coordinates of x:13.871449376499825 y:19.639549279659402 Theta:0.0
# Current node is in region coordinates of [12, 8, 0]
# Current node has exact coordinates of x:16.990250949881343 y:38.31867302624896 Theta:35.6724294813467
# Current node is in region coordinates of [25, 10, 9]
# Current node has exact coordinates of x:14.669652939056226 y:15.335596239818232 Theta:59.454049135577804
# Current node is in region coordinates of [10, 9, 5]
# Current node has exact coordinates of x:17.10131354489005 y:22.188262473267113 Theta:0.0
# Current node is in region coordinates of [14, 11, 0]
# Current node has exact coordinates of x:17.23788880230962 y:26.0837276324672 Theta:71.34485896269334
# Current node is in region coordinates of [17, 11, 4]
# Current node has exact coordinates of x:16.596818453482385 y:22.397956760903856 Theta:47.56323930846229
# Current node is in region coordinates of [14, 10, 6]
# Current node has exact coordinates of x:14.374097076757353 y:31.481401134045694 Theta:71.34485896269334
# Current node is in region coordinates of [20, 9, 4]
# Current node has exact coordinates of x:4.665657928737399 y:11.981040941208141 Theta:47.56323930846234
# Current node is in region coordinates of [7, 2, 6]
# Current node has exact coordinates of x:19.96659459565765 y:28.849980054520767 Theta:35.6724294813467
# Current node is in region coordinates of [18, 12, 9]
# Current node has exact coordinates of x:14.795383507021675 y:19.215390330177364 Theta:71.34485896269345
# Current node is in region coordinates of [12, 9, 4]
# Current node has exact coordinates of x:13.366954285092179 y:19.849243567296142 Theta:47.56323930846229
# Current node is in region coordinates of [12, 8, 6]
# Current node has exact coordinates of x:17.936712996961916 y:25.75852184483431 Theta:95.12647861692452
# Current node is in region coordinates of [16, 11, 2]
# Current node has exact coordinates of x:15.717965761608635 y:22.76481362680263 Theta:0.0
# Current node is in region coordinates of [14, 10, 0]
# Current node has exact coordinates of x:19.759886900201906 y:32.8830920202918 Theta:35.6724294813467
# Current node is in region coordinates of [21, 12, 9]
# Current node has exact coordinates of x:15.958687144852398 y:22.653940118418006 Theta:71.34485896269345
# Current node is in region coordinates of [14, 10, 4]
# Current node has exact coordinates of x:15.888872673372752 y:18.72735655224052 Theta:83.235668789809
# Current node is in region coordinates of [12, 10, 3]
# Current node has exact coordinates of x:5.734889717701099 y:3.364536126942461 Theta:83.23566878980891
# Current node is in region coordinates of [2, 3, 3]
# Current node has exact coordinates of x:16.876965394488046 y:34.24791759683498 Theta:71.34485896269334
# Current node is in region coordinates of [22, 10, 4]
# Current node has exact coordinates of x:18.94782992999886 y:25.313526820410345 Theta:0.0
# Current node is in region coordinates of [16, 12, 0]
# Current node has exact coordinates of x:16.14867120856186 y:34.618505121515675 Theta:47.56323930846219
# Current node is in region coordinates of [22, 10, 6]
# Current node has exact coordinates of x:18.44333483859119 y:25.523221108047093 Theta:47.56323930846229
# Current node is in region coordinates of [16, 12, 6]
# Current node has exact coordinates of x:10.641585208109621 y:17.09083608605167 Theta:0.0
# Current node is in region coordinates of [11, 6, 0]
# Current node has exact coordinates of x:6.557255752494298 y:15.049003204768093 Theta:71.3448589626935
# Current node is in region coordinates of [10, 4, 4]
# Current node has exact coordinates of x:17.56448214671745 y:25.890077973945868 Theta:0.0
# Current node is in region coordinates of [16, 11, 0]
# Current node has exact coordinates of x:11.164229756557118 y:16.828074118699497 Theta:35.6724294813467
# Current node is in region coordinates of [10, 7, 9]
# Current node has exact coordinates of x:12.488101593218426 y:20.216100433194914 Theta:0.0
# Current node is in region coordinates of [13, 8, 0]
# Current node has exact coordinates of x:19.502492350597713 y:32.96810956387247 Theta:47.56323930846219
# Current node is in region coordinates of [21, 12, 6]
# Current node has exact coordinates of x:21.166577165352134 y:28.307235038442027 Theta:95.12647861692452
# Current node is in region coordinates of [18, 14, 2]
# Current node has exact coordinates of x:15.070817075283678 y:39.316095763884 Theta:59.454049135577804
# Current node is in region coordinates of [26, 10, 5]
# Current node has exact coordinates of x:16.917333460392488 y:42.44136011102727 Theta:59.454049135577804
# Current node is in region coordinates of [28, 10, 5]
# Current node has exact coordinates of x:11.722845682452142 y:28.714597544960398 Theta:23.78161965423118
# Current node is in region coordinates of [18, 7, 2]
# Current node has exact coordinates of x:18.651539526292552 y:37.38502158430496 Theta:47.56323930846219
# Current node is in region coordinates of [24, 12, 6]
# Current node has exact coordinates of x:17.59017267709225 y:37.92522551478703 Theta:118.90809827115561
# Current node is in region coordinates of [24, 11, 2]
# Current node has exact coordinates of x:14.334617978327236 y:23.341364780338147 Theta:0.0
# Current node is in region coordinates of [15, 9, 0]
# Current node has exact coordinates of x:20.2898512237 y:28.64848545519033 Theta:47.56323930846229
# Current node is in region coordinates of [18, 13, 6]
# Current node has exact coordinates of x:17.7332612766569 y:25.791044105887988 Theta:47.5632393084623
# Current node is in region coordinates of [16, 11, 6]
# Current node has exact coordinates of x:20.79434631510767 y:28.43879116755358 Theta:0.0
# Current node is in region coordinates of [18, 13, 0]
# Current node has exact coordinates of x:18.488416277239285 y:25.465919024463812 Theta:71.34485896269345
# Current node is in region coordinates of [16, 12, 4]
# Current node has exact coordinates of x:8.331829884298797 y:18.186107192238076 Theta:47.56323930846236
# Current node is in region coordinates of [12, 5, 6]
# Current node has exact coordinates of x:19.41099853182626 y:29.0153423210891 Theta:0.0
# Current node is in region coordinates of [19, 12, 0]
# Current node has exact coordinates of x:18.362685709273848 y:21.586124934104713 Theta:59.454049135577804
# Current node is in region coordinates of [14, 12, 5]
# Current node has exact coordinates of x:9.00219628736208 y:26.043687820207857 Theta:59.454049135577804
# Current node is in region coordinates of [17, 6, 5]
# Current node has exact coordinates of x:17.19989902909484 y:30.003082361591794 Theta:35.6724294813467
# Current node is in region coordinates of [20, 11, 9]
# Current node has exact coordinates of x:9.640969999490665 y:13.501315172225828 Theta:47.56323930846229
# Current node is in region coordinates of [8, 6, 6]
# Current node has exact coordinates of x:19.651719915070007 y:28.904468812704454 Theta:71.34485896269345
# Current node is in region coordinates of [18, 12, 4]
# Current node has exact coordinates of x:7.72055939032501 y:18.487552993008737 Theta:71.3448589626935
# Current node is in region coordinates of [12, 4, 4]
# Current node has exact coordinates of x:16.181134363436033 y:26.46662912748139 Theta:0.0
# Current node is in region coordinates of [17, 10, 0]
# Current node has exact coordinates of x:13.830122886919582 y:23.551059067974887 Theta:47.56323930846229
# Current node is in region coordinates of [15, 8, 6]
# Current node has exact coordinates of x:13.264266664279836 y:31.9707446311786 Theta:35.6724294813467
# Current node is in region coordinates of [20, 8, 9]
# Current node has exact coordinates of x:12.912108847283813 y:23.990379367039143 Theta:35.67242948134671
# Current node is in region coordinates of [15, 8, 9]
# Current node has exact coordinates of x:16.272628182207526 y:30.41939637026475 Theta:47.56323930846219
# Current node is in region coordinates of [20, 10, 6]
# Current node has exact coordinates of x:20.33493266234809 y:28.59118337160705 Theta:71.34485896269345
# Current node is in region coordinates of [18, 13, 4]
# Current node has exact coordinates of x:14.393260024085926 y:35.47391202196315 Theta:118.90809827115561
# Current node is in region coordinates of [23, 9, 2]
# Current node has exact coordinates of x:16.239776409194736 y:38.599176369106424 Theta:118.90809827115561
# Current node is in region coordinates of [25, 10, 2]
# Current node has exact coordinates of x:10.223427708055691 y:21.25406945579803 Theta:71.3448589626935
# Current node is in region coordinates of [14, 6, 4]
# Current node has exact coordinates of x:9.495133522129507 y:21.62465698047872 Theta:47.56323930846236
# Current node is in region coordinates of [14, 6, 6]
# Current node has exact coordinates of x:20.209202094382658 y:24.71138928124795 Theta:59.454049135577804
# Current node is in region coordinates of [16, 13, 5]
# Current node has exact coordinates of x:10.989167657934766 y:29.044748851804812 Theta:107.01728844404016
# Current node is in region coordinates of [19, 6, 2]
# Current node has exact coordinates of x:12.835684043043576 y:32.17001319894805 Theta:107.01728844404016
# Current node is in region coordinates of [21, 8, 2]
# Current node has exact coordinates of x:8.762117307616919 y:13.86817203812459 Theta:0.0
# Current node is in region coordinates of [8, 5, 0]
# Current node has exact coordinates of x:17.758514954989852 y:41.889605787852744 Theta:23.78161965423118
# Current node is in region coordinates of [27, 11, 2]
# ...
# Current node is in region coordinates of [16, 6, 4]
# Current node has exact coordinates of x:19.5381940754769 y:28.847203000177 Theta:23.781619654231203
# Current node is in region coordinates of [18, 12, 2]
# Current node has exact coordinates of x:9.007820001801388 y:17.726994029998462 Theta:71.3448589626935
# Current node is in region coordinates of [11, 6, 4]
# Current node has exact coordinates of x:19.414753480894092 y:32.86955002582131 Theta:71.34485896269345
# Current node is in region coordinates of [21, 12, 4]
# Current node has exact coordinates of x:17.20086631768067 y:21.950683238990997 Theta:47.56323930846229
# Current node is in region coordinates of [14, 11, 6]
# Current node has exact coordinates of x:11.950654986426883 y:20.328395020047804 Theta:47.56323930846229
# Current node is in region coordinates of [13, 7, 6]
# Current node has exact coordinates of x:20.689131319223918 y:28.358589805067588 Theta:83.235668789809
# Current node is in region coordinates of [18, 13, 3]
# Current node has exact coordinates of x:11.38479876378714 y:28.74808058325152 Theta:35.6724294813467
# Current node is in region coordinates of [18, 7, 9]
# Current node has exact coordinates of x:4.415966939732043 y:11.901069639942978 Theta:83.235668789809
# Current node is in region coordinates of [7, 2, 3]
# Current node has exact coordinates of x:17.64337346125549 y:37.75142652310084 Theta:83.235668789809
# Current node is in region coordinates of [24, 11, 3]
# Current node has exact coordinates of x:11.82174079779095 y:28.501756556960004 Theta:47.56323930846236
# Current node is in region coordinates of [18, 7, 6]
# Current node has exact coordinates of x:10.782394133605886 y:20.864098017468443 Theta:47.56323930846236
# Current node is in region coordinates of [13, 6, 6]
# Current node has exact coordinates of x:6.165106804144625 y:6.96895192683737 Theta:83.23566878980891
# Current node is in region coordinates of [4, 4, 3]
# Current node has exact coordinates of x:8.745303525271883 y:5.795333349258567 Theta:11.890809827115586
# Current node is in region coordinates of [3, 5, 5]
# Current node has exact coordinates of x:17.245947756328768 y:21.893381155407727 Theta:71.34485896269345
# Current node is in region coordinates of [14, 11, 4]
# Current node has exact coordinates of x:17.05225541548129 y:18.039989002861894 Theta:35.6724294813467
# Current node is in region coordinates of [12, 11, 9]
# Current node has exact coordinates of x:11.210470303817175 y:28.803202357730665 Theta:71.3448589626935
# Current node is in region coordinates of [18, 7, 4]
# Current node has exact coordinates of x:13.842252810183787 y:23.39635728360776 Theta:71.34485896269345
# Current node is in region coordinates of [15, 8, 4]
# Current node has exact coordinates of x:17.761447149115238 y:29.576955460865644 Theta:11.890809827115525
# Current node is in region coordinates of [19, 11, 5]
# Current node has exact coordinates of x:11.071802294553137 y:20.69525188594658 Theta:0.0
# Current node is in region coordinates of [13, 7, 0]
# Current node has exact coordinates of x:13.713338621547845 y:31.56971882051996 Theta:71.3448589626935
# Current node is in region coordinates of [20, 8, 4]
# Current node has exact coordinates of x:10.591819910380698 y:8.92059769640181 Theta:11.890809827115586
# Current node is in region coordinates of [5, 6, 5]
# Current node has exact coordinates of x:5.590260772017755 y:15.326383535231551 Theta:107.01728844404016
# Current node is in region coordinates of [10, 3, 2]
# Current node has exact coordinates of x:14.410568909107512 y:39.48519202837921 Theta:83.235668789809
# Current node is in region coordinates of [26, 9, 3]
# Current node has exact coordinates of x:5.0958750151809165 y:15.58545674110305 Theta:47.56323930846234
# Current node is in region coordinates of [10, 3, 6]
# Current node has exact coordinates of x:15.747144937748933 y:34.583377452032856 Theta:59.454049135577804
# Current node is in region coordinates of [22, 10, 5]
# Current node has exact coordinates of x:12.985044435621672 y:31.940306345200646 Theta:47.56323930846236
# Current node is in region coordinates of [20, 8, 6]
# Current node has exact coordinates of x:8.341948121185915 y:26.21278408470306 Theta:83.235668789809
# Current node is in region coordinates of [17, 5, 3]
# Current node has exact coordinates of x:11.311881274298289 y:32.87076766802985 Theta:59.454049135577804
# Current node is in region coordinates of [21, 7, 5]
# Current node has exact coordinates of x:13.158397659407099 y:35.99603201517312 Theta:59.454049135577804
# Current node is in region coordinates of [23, 8, 5]
# Current node has exact coordinates of x:17.380502062219893 y:46.14317561170598 Theta:59.454049135577804
# Current node is in region coordinates of [30, 11, 5]
# Current node has exact coordinates of x:19.227018447328703 y:49.26843995884925 Theta:59.454049135577804
# Current node is in region coordinates of [32, 12, 5]
# Current node has exact coordinates of x:21.073534832437513 y:52.39370430599252 Theta:59.454049135577804
# Current node is in region coordinates of [34, 14, 5]
# Current node has exact coordinates of x:22.920051217546323 y:55.51896865313579 Theta:59.454049135577804
# Current node is in region coordinates of [36, 14, 5]
# Current node has exact coordinates of x:24.766567602655133 y:58.644233000279065 Theta:59.454049135577804
# Current node is in region coordinates of [38, 16, 5]
# Current node has exact coordinates of x:26.613083987763943 y:61.76949734742234 Theta:59.454049135577804
# Current node is in region coordinates of [40, 17, 5]
# Current node has exact coordinates of x:28.459600372872753 y:64.8947616945656 Theta:59.454049135577804
# Current node is in region coordinates of [42, 18, 5]
# Current node has exact coordinates of x:30.306116757981563 y:68.02002604170887 Theta:59.454049135577804
# Current node is in region coordinates of [45, 20, 5]
# Current node has exact coordinates of x:32.15263314309038 y:71.14529038885215 Theta:59.454049135577804
# Current node is in region coordinates of [47, 21, 5]
# Current node has exact coordinates of x:17.10747156709085 y:33.870260128838886 Theta:0.0
# Current node is in region coordinates of [22, 11, 0]
# Current node has exact coordinates of x:12.438336295489506 y:12.045862043545052 Theta:11.890809827115586
# Current node is in region coordinates of [8, 8, 5]
# Current node has exact coordinates of x:33.999149528199226 y:74.27055473599542 Theta:59.454049135577804
# Current node is in region coordinates of [49, 22, 5]
# Current node has exact coordinates of x:10.07118708593418 y:17.105730972120735 Theta:47.56323930846229
# Current node is in region coordinates of [11, 6, 6]
# Current node has exact coordinates of x:7.255572056764315 y:10.40427146223707 Theta:59.45404913557774
# Current node is in region coordinates of [6, 4, 5]
# Current node has exact coordinates of x:35.845665913308075 y:77.39581908313869 Theta:59.454049135577804
# Current node is in region coordinates of [51, 23, 5]
# Current node has exact coordinates of x:37.692182298416924 y:80.52108343028196 Theta:59.454049135577804
# Current node is in region coordinates of [53, 24, 5]
# Current node has exact coordinates of x:5.50643219235173 y:15.336389175342683 Theta:59.454049135577804
# Current node is in region coordinates of [10, 3, 5]
# Current node has exact coordinates of x:39.53869868352577 y:83.64634777742523 Theta:59.454049135577804
# Current node is in region coordinates of [55, 26, 5]
# Current node has exact coordinates of x:41.38521506863462 y:86.7716121245685 Theta:59.454049135577804
# Current node is in region coordinates of [57, 27, 5]
# Current node has exact coordinates of x:18.95398795219966 y:36.99552447598216 Theta:0.0
# Current node is in region coordinates of [24, 12, 0]
# Current node has exact coordinates of x:5.579349681840571 y:11.213702090564356 Theta:35.6724294813467
# Current node is in region coordinates of [7, 3, 9]
# Current node has exact coordinates of x:43.23173145374347 y:89.89687647171178 Theta:59.454049135577804
# Current node is in region coordinates of [59, 28, 5]
# Current node has exact coordinates of x:15.136324818180354 y:14.83886840202377 Theta:35.6724294813467
# Current node is in region coordinates of [9, 10, 9]
# Current node has exact coordinates of x:12.373773941647897 y:32.24175214597131 Theta:71.3448589626935
# Current node is in region coordinates of [21, 8, 4]
# Current node has exact coordinates of x:14.448566089167281 y:27.069164268498376 Theta:47.56323930846236
# Current node is in region coordinates of [18, 9, 6]
# Current node has exact coordinates of x:14.531582980725037 y:27.028242267257912 Theta:11.890809827115525
# Current node is in region coordinates of [18, 9, 5]
# Current node has exact coordinates of x:14.876642259378567 y:35.0082686087606 Theta:71.3448589626935
# Current node is in region coordinates of [23, 9, 4]
# Current node has exact coordinates of x:16.702945011022134 y:42.30099186978513 Theta:118.90809827115561
# Current node is in region coordinates of [28, 10, 2]
# Current node has exact coordinates of x:18.549461396130948 y:45.4262562169284 Theta:118.90809827115561
# Current node is in region coordinates of [30, 12, 2]
# Current node has exact coordinates of x:7.425866066949384 y:14.3389664377076 Theta:35.6724294813467
# Current node is in region coordinates of [9, 4, 9]
# Current node has exact coordinates of x:13.917389175653991 y:31.403498128030513 Theta:83.235668789809
# Current node is in region coordinates of [20, 8, 3]
# Current node has exact coordinates of x:45.07824783885232 y:93.02214081885505 Theta:59.454049135577804
# Current node is in region coordinates of [62, 30, 5]
# Current node has exact coordinates of x:10.565572842771024 y:16.846657766249237 Theta:107.0172884440401
# Current node is in region coordinates of [10, 6, 2]
# Current node has exact coordinates of x:6.508057601853718 y:2.720928666676651 Theta:47.56323930846223
# Current node is in region coordinates of [1, 4, 6]
# Current node has exact coordinates of x:19.682777302563938 y:32.615715182446046 Theta:59.454049135577804
# Current node is in region coordinates of [21, 12, 5]
# Current node has exact coordinates of x:14.754725730199942 y:26.896401661998297 Theta:107.0172884440401
# Current node is in region coordinates of [17, 9, 2]
# Current node has exact coordinates of x:8.78780783799173 y:25.90331957896576 Theta:118.90809827115561
# Current node is in region coordinates of [16, 5, 2]
# Current node has exact coordinates of x:12.734212369240153 y:11.878966321448855 Theta:0.0
# Current node is in region coordinates of [7, 8, 0]
# Current node has exact coordinates of x:11.37387783577062 y:8.512483454042387 Theta:35.6724294813467
# Current node is in region coordinates of [5, 7, 9]
# Current node has exact coordinates of x:14.82457705793624 y:35.010993678281835 Theta:47.56323930846234
# Current node is in region coordinates of [23, 9, 6]
# Current node has exact coordinates of x:11.118898837167006 y:20.58949513199407 Theta:35.6724294813467
# Current node is in region coordinates of [13, 7, 9]
# Current node has exact coordinates of x:46.92476422396117 y:96.14740516599832 Theta:59.454049135577804
# Current node is in region coordinates of [64, 30, 5]
# Current node has exact coordinates of x:16.651216391183066 y:38.14537259623058 Theta:47.56323930846236
# Current node is in region coordinates of [25, 10, 6]
# Current node has exact coordinates of x:16.966364672065463 y:37.975137764455134 Theta:83.235668789809
# Current node is in region coordinates of [24, 10, 3]
# Current node has exact coordinates of x:8.47479179108085 y:13.796031774659347 Theta:83.23566878980891
# Current node is in region coordinates of [8, 5, 3]
# Current node has exact coordinates of x:20.745288185698907 y:24.290517697148378 Theta:35.6724294813467
# Current node is in region coordinates of [16, 13, 9]
# Current node has exact coordinates of x:11.962784909691084 y:20.17369323568069 Theta:71.34485896269345
# Current node is in region coordinates of [13, 7, 4]
# Current node has exact coordinates of x:11.411639213077814 y:12.439975475859178 Theta:23.78161965423118
# Current node is in region coordinates of [8, 7, 2]
# Current node has exact coordinates of x:3.6734409180042293 y:12.146946165979914 Theta:83.23566878980897
# Current node is in region coordinates of [8, 2, 3]
# Current node has exact coordinates of x:16.982841203289166 y:17.964132749166993 Theta:35.6724294813467
# Current node is in region coordinates of [11, 10, 9]
# Current node has exact coordinates of x:7.230231856949378 y:22.599420755950653 Theta:107.01728844404016
# Current node is in region coordinates of [14, 4, 2]
# Current node has exact coordinates of x:3.630000000000001 y:0.0 Theta:0.0
# Current node is in region coordinates of [0, 2, 0]
# Current node has exact coordinates of x:16.71617488169313 y:38.078955941841784 Theta:71.3448589626935
# Current node is in region coordinates of [25, 10, 4]
# Current node has exact coordinates of x:14.580728754348963 y:15.004230668592095 Theta:0.0
# Current node is in region coordinates of [10, 9, 0]
# Current node has exact coordinates of x:12.531101008614815 y:36.26252798045213 Theta:83.235668789809
# Current node is in region coordinates of [24, 8, 3]
# Current node has exact coordinates of x:13.53707757947862 y:35.680301934211954 Theta:71.3448589626935
# Current node is in region coordinates of [23, 8, 4]
# Current node has exact coordinates of x:13.867677037256238 y:31.36071340410578 Theta:59.454049135577804
# Current node is in region coordinates of [20, 8, 5]
# Current node has exact coordinates of x:19.940410656556974 y:32.44585603835925 Theta:23.78161965423107
# Current node is in region coordinates of [21, 12, 2]
# Current node has exact coordinates of x:19.763104538644953 y:48.84756837474964 Theta:35.6724294813467
# Current node is in region coordinates of [32, 12, 9]
# Current node has exact coordinates of x:21.609620923753763 y:51.972832721892914 Theta:35.6724294813467
# Current node is in region coordinates of [34, 14, 9]
# Current node has exact coordinates of x:25.302653693971383 y:58.22336141617946 Theta:35.6724294813467
# Current node is in region coordinates of [38, 16, 9]
# Current node has exact coordinates of x:27.149170079080193 y:61.34862576332273 Theta:35.6724294813467
# Current node is in region coordinates of [40, 18, 9]
# Current node has exact coordinates of x:28.995686464189003 y:64.473890110466 Theta:35.6724294813467
# Current node is in region coordinates of [42, 18, 9]
# Current node has exact coordinates of x:30.842202849297813 y:67.59915445760927 Theta:35.6724294813467
# Current node is in region coordinates of [44, 20, 9]
# Current node has exact coordinates of x:32.68871923440662 y:70.72441880475255 Theta:35.6724294813467
# Current node is in region coordinates of [46, 21, 9]
# Current node has exact coordinates of x:34.53523561951544 y:73.84968315189582 Theta:35.6724294813467
# Current node is in region coordinates of [48, 22, 9]
# Current node has exact coordinates of x:36.38175200462429 y:76.97494749903909 Theta:35.6724294813467
# Current node is in region coordinates of [50, 24, 9]
# Current node has exact coordinates of x:38.22826838973314 y:80.10021184618236 Theta:35.6724294813467
# Current node is in region coordinates of [53, 25, 9]
# Current node has exact coordinates of x:40.07478477484199 y:83.22547619332563 Theta:35.6724294813467
# Current node is in region coordinates of [55, 26, 9]
# Current node has exact coordinates of x:41.921301159950836 y:86.3507405404689 Theta:35.6724294813467
# Current node is in region coordinates of [57, 27, 9]
# Current node has exact coordinates of x:43.767817545059685 y:89.47600488761218 Theta:35.6724294813467
# Current node is in region coordinates of [59, 28, 9]
# Current node has exact coordinates of x:45.614333930168534 y:92.60126923475545 Theta:35.6724294813467
# Current node is in region coordinates of [61, 30, 9]
# Current node has exact coordinates of x:47.46085031527738 y:95.72653358189872 Theta:35.6724294813467
# Current node is in region coordinates of [63, 31, 9]
# Current node has exact coordinates of x:49.30736670038623 y:98.851797929042 Theta:35.6724294813467
# Current node is in region coordinates of [65, 32, 9]
# Found Solution
# Animating Search Pattern

# %%
plt.figure(figsize=(10, 10))
plt.imshow(color_map, origin = "bottom")

# %%
len(commands)
# Out:
# 31
