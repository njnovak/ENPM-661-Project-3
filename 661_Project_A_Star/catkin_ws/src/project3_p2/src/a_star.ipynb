# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from copy import deepcopy
import cv2
from cv2 import VideoWriter, VideoWriter_fourcc
import sys
import math

# %%
r = 0.038*20
L = 0.354*20

# %%
# node class that each spot in the map will occupy
# cell location and goal_location are tuples representing index 
# of current cell location and goal cell locations
# local path represents the path to get to this 
# node from the optimal parent node
class Node:
    def __init__(self, parent, cell_location, region, c2c, c2g, local_path, command):
        self.parent = parent
        self.cell_location = cell_location
        self.region = region
        self.c2c = c2c
        self.c2g = c2g
        self.h = c2c+c2g
        self.local_path = local_path
        self.command = command

# %%
# given 2 points of a line, retrun a lambda function which caluclates the 
# y value of an x
def generate_line_eq(p1, p2):
    
    x1 = p1[0]
    y1 = p1[1]
    
    x2 = p2[0]
    y2 = p2[1]
    
    m = (y2-y1)/(x2-x1)
    b = y1-m*x1
    
    lin_func = lambda x: m*x+b
    
    return lin_func

# %%
# hardcoded obstacles defined by their vertices and origins
# we just see if the current x and y are within bounding lines
def check_obstacle(x, y):
    
    # check bottom circle
    if y <= 60 and y >= 20 and x <= np.sqrt(20**2 - (y-40)**2) + 40 and x >= -np.sqrt(20**2 - (y-40)**2) + 40:
        return True

    #check top circle
    if y <= 180 and y >= 140 and x <= np.sqrt(20**2 - (y-160)**2) + 40 and x >= -np.sqrt(20**2 - (y-160)**2) + 40:
        return True

    # check left square
    if x >= 5 and x <= 35 and y >= 85 and y <= 115:
        return True

    # check middle rectangle
    if x >= 75 and x <= 125 and y >= 85 and y <= 115:
        return True

    # check right rectangle
    if x >= 145 and x <= 175 and y >= 40 and y <= 80:
        return True
    

    return False

# %%
# iterate over the board, and if the cell is an obstacle, generate 
# the a circle of points around it which are padding
def generate_margin(color_map, radius):

    height = len(color_map)
    width = len(color_map[0])

    for y in range(len(color_map)):
        for x in range(len(color_map[y])):

            # read the color map and check to see if the current space is an obstacle
            if (color_map[y][x][0] == 255 and color_map[y][x][1] == 0 and 
                color_map[y][x][2] == 0):

                # generate circle bounds for a point if it is an obstacle
                x_range = range(x-radius, x+radius+1)

                for x_i in x_range:
                    y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
                    y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

                    y_range = np.arange(y_lower_limit, y_upper_limit+1)
                    for y_i in y_range:
                        if (x_i >= 0 and x_i < width) and (y_i >= 0 and y_i < height):
                            if not (color_map[int(y_i)][x_i][0] == [255] and 
                                    color_map[int(y_i)][x_i][1] == [0] and 
                                    color_map[int(y_i)][x_i][2] == [0]):
                                color_map[int(y_i)][x_i] = [0,255,0]
    return color_map

# %%
# draw a circle (red in numpy, blue in opencv) to represent the acceptable goal zone
def expand_goal(color_map, goal_location, radius):

    x = goal_location[1]
    y = goal_location[0]

    height = len(color_map)
    width = len(color_map[0])

    x_range = range(x-radius, x+radius+1)
    for x_i in x_range:
        y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
        y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

        y_range = np.arange(y_lower_limit, y_upper_limit+1)
        for y_i in y_range:
            if (x_i >= 0 and x_i < width) and (y_i >= 0 and y_i < height):
                if not (int(color_map[int(y_i)][int(x_i)][0]) == 255 or\
                       int(color_map[int(y_i)][int(x_i)][1]) == 255):
                    color_map[int(y_i)][int(x_i)] = [0,0,255]

    return color_map

# %%
# read the board and depending on each nodes status
# write the proper color in a numpy array as BGR colors
def create_color_map(height, width, radius, goal_location):

    color_map = np.zeros(shape=[height, width, 3], dtype=np.uint8)

    for row in range(height):
        for col in range(width):
            if check_obstacle(col, row):
                color_map[row][col][0] = 255
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

            else:
                color_map[row][col][0] = 0
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

    color_map = expand_goal(color_map, goal_location, 2)
    color_map = generate_margin(color_map, radius)

    return color_map

# %%
# pass in color map coordinates and convert them to board 
# coordinates which have been compressed/expanded coordinates 
# by the neighborhood threshold
def compress_coordinates(x, y, theta, thresh):
    compressed_x = int(np.floor(x/thresh))
    compressed_y = int(np.floor(y/thresh))

    theta = theta % 360
    compressed_angle = (int(np.floor(theta/30)))%11

    return compressed_x, compressed_y, compressed_angle

# %%
# will be used when iterating over closed nodes
# updates the previous color map given the current node to a specifies color
def update_color_map(curr_node, color_map, brg_color):

    row = int(np.floor(curr_node.cell_location[0]))
    col = int(np.floor(curr_node.cell_location[1]))

    color_map[row][col][0] = brg_color[0]
    color_map[row][col][1] = brg_color[1]
    color_map[row][col][2] = brg_color[2]

    return color_map

# %%
# create the board
# returns a 3d array
# dimensions are height width and angle. Takes in a compressed version of 
# the height width and angle which handles the region/node similarity
def create_board(width, height, thresh):

    compressed_width, compressed_height, compressed_angle = compress_coordinates(x=width, y=height, theta=30, thresh=thresh)

    board = []
    for row_num in range(0, compressed_height):
        temp_row = []
        for col_num in range(0, compressed_width):

            temp_configuration = []
            for angle in range(0,12):

                c2c = np.Infinity
                c2g = np.Infinity

                # c2g = np.sqrt((row_num-goal_location[0])**2 + (col_num-goal_location[1]**2))

                new_node = Node(parent=None, 
                                c2c=c2c,
                                c2g=c2g,
                                cell_location=[int(row_num*thresh), int(col_num*thresh), angle*30],
                                region=[row_num, col_num, angle],
                                local_path=[],
                                command = [0,0])

                temp_configuration.append(new_node)
            temp_row.append(temp_configuration)
        board.append(temp_row)

    return board

# %%
# generates a series of x and y values representing a curve given wheel velocities
# also returns the final theta orientation of the node, as well as the total cost of the path
# path validity is not checked here
def generate_curve(x,y,theta,UL,UR):

    # robot parameters
    t = 0
    
    dt = 0.05
    cost= 0


    # list of x and y values
    # will be set to the nodes local_path so we can graph it
    x_res = [x]
    y_res = [y]

    theta = 3.14 * theta / 180

    # generate the subpoints for the curve and
    # append the points to the x and y list
    while t<1:
        t = t + dt
        x += 0.5*r * (UL + UR) * math.cos(theta) * dt
        y += 0.5*r * (UL + UR) * math.sin(theta) * dt
        theta += (r / L) * (UR - UL) * dt
        cost = cost+ math.sqrt(math.pow((0.5*r * (UL + UR) * math.cos(theta) * dt),2)+math.pow((0.5*r * (UL + UR) * math.sin(theta) * dt),2))
        
        x_res.append(x)
        y_res.append(y)
        
    theta = 180 * (theta) / 3.14
    
    # retrun the x and ys to be plotted as well as the end theta, and cost of the curve 
    return x_res, y_res, theta, cost

# %%
# uses the predefined differential commands to generate the arc of the robots path
# for each point in the arc, check bounds and if in opstacle or margin, and disqualify arcs which contain invalid points
# if arc is valid then pull the node it ends on compare costs, and if cheaper, then update the cost and local path to the node
def gen_next_nodes(curr_node, color_map, board, goal_location, thresh, rpms):

    curr_y = curr_node.cell_location[0]
    curr_x = curr_node.cell_location[1]
    curr_angle = curr_node.cell_location[2]

    next_nodes = []

    actions=[[10, 6], [10, 0], [5, 5], [0,10], [6, 10]]
    # actions = [
    #     [rpms[0], 0],
    #     [0, rpms[0]],
    #     [rpms[0], rpms[0]],
    #     [rpms[1], 0],
    #     [0, rpms[1]],
    #     [rpms[1], rpms[1]],
    #     [rpms[0], rpms[1]],
    #     [rpms[1], rpms[0]]
    # ]

    for action in actions:

        x_res, y_res, theta, cost = generate_curve(curr_x, curr_y, curr_angle, action[0], action[1])

        valid = True

        # bounds checking
        for x in x_res:
            if int(x) < 0 or int(x) > 399:
                valid = False
        for y in y_res:
            if int(y) < 0 or int(y) > 249:
                valid = False

        # obstacle or margin checking
        if valid:
            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

        
        if valid:

            # use compressed coordinates to access a new node
            comp_x, comp_y, comp_angle = compress_coordinates(
                math.floor(x_res[-1]),
                math.floor(y_res[-1]),
                theta,
                thresh=thresh
            )

            c2c = curr_node.c2c + cost
            c2g = np.sqrt((x_res[-1]-goal_location[1])**2 + (y_res[-1]-goal_location[0])**2)
            h = c2g+c2c


            new_node = board[comp_y][comp_x][comp_angle]
            if h < new_node.h:
                new_node.parent = curr_node
                new_node.cell_location = [y_res[-1], x_res[-1], theta]
                new_node.c2c = c2c
                new_node.c2g = c2g
                new_node.h = h
                new_node.local_path = [x_res, y_res]
                new_node.command = action

            next_nodes.append(new_node)
                

    return next_nodes

# %%
# this is the backtracking function
# returns a list of nodes in order to find the solution
def get_solution_path(curr_node):
    solution_path= []
    
    while curr_node:
        solution_path.insert(0, curr_node)
        curr_node = curr_node.parent
        
    return solution_path

# %%
# plot the chronologically ordered list of nodes in closed nodes, and then generate and plot the path for the solution
def animate(color_map, closed_nodes, solution_path):

    # draw explored nodes
    out = cv2.VideoWriter('test.avi',cv2.VideoWriter_fourcc(*'DIVX'), 60, (200, 200))
    for node in closed_nodes[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[255, 255, 255],1)        
                out.write(np.flipud(color_map))


    # draw the backtracked best path
    for node in solution_path[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[0, 0, 255],1)        
                out.write(np.flipud(color_map))

    out.release()

# %%
# starting paramters
start_location = [5,5,0]
goal_location = [75,100,0]

# robot_radius = 0.177 m * 20 blocks/meter = 3.54 round up to 4
clearance = 2
rpms = [3, 7]


# color map size
# board size will be based off of the color map and threshold
width = 200
height = 200
thresh = 2

print('Building Color Map')
color_map = create_color_map(height = height, width = width, radius=4 + clearance, goal_location=goal_location)

print('Building Board')
board = create_board(width=width, height=height, thresh=thresh)

plt.figure(figsize=(10, 10))
plt.imshow(color_map, origin='lower')

compressed_x_start, compressed_y_start, compressed_angle_start = compress_coordinates(
        start_location[1],
        start_location[0],
        start_location[2],
        thresh=thresh
    )

compressed_x_goal, compressed_y_goal, compressed_angle_goal = compress_coordinates(
    goal_location[1],
    goal_location[0],
    goal_location[2],
    thresh=thresh
)

print(f'Starting in region x: {compressed_x_start}, y: {compressed_y_start}, theta: {compressed_angle_start}')
print(f'Goal in region x: {compressed_x_goal}, y: {compressed_y_goal}, theta: {compressed_angle_goal}')
# Out:
# Building Color Map
# Building Board
# Starting in region x: 2, y: 2, theta: 0
# Goal in region x: 50, y: 37, theta: 0

# %%
start_node = board[compressed_y_start][compressed_x_start][compressed_angle_start]
goal_node = board[compressed_y_goal][compressed_x_goal][compressed_angle_goal]

start_node.c2c = 0
goal_region = goal_node.region

open_nodes = [start_node]
closed_nodes = []

found = False
solution_path = None
commands = None

print(f'Searching for goal region: {goal_region}')
while len(open_nodes) > 0:

    open_nodes.sort(key=lambda x: x.h)
    curr_node = open_nodes.pop(0)
    closed_nodes.append(curr_node)

    curr_x = curr_node.cell_location[1]
    curr_y = curr_node.cell_location[0]

    print(f"Current node has exact coordinates of {curr_node.cell_location}")
    print(f"Current node is in region coordinates of {curr_node.region}")

    if int(color_map[int(curr_y)][int(curr_x)][0]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][1]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][2]) == 255:
    # if curr_node.region[:2] == goal_node.region[:2]:
        print('Found Solution')
        found = True

        print('Animating Search Pattern')          
        # back track and animate the search and solution
        solution_path = get_solution_path(curr_node)
        # commands = get_commands(solution_path)
        # animate(color_map, closed_nodes, solution_path)

        break

    else:
        next_possible_nodes = gen_next_nodes(
            curr_node=curr_node,
            board=board,
            goal_location=goal_location,
            color_map=color_map,
            thresh=thresh,
            rpms = rpms
        )
        
        for node in next_possible_nodes:

            appendable = True
            for o_node in open_nodes:
                if o_node.region == node.region:
                    appendable = False
                    break
            if appendable:
                for c_node in closed_nodes:
                    if c_node.region == node.region:
                        appendable = False
                        break

            if appendable:
                open_nodes.append(node)

if not found:
    print('No Solution')
# Out:
# Searching for goal region: [37, 50, 0]
# Current node has exact coordinates of [4, 4, 0]
# Current node is in region coordinates of [2, 2, 0]
# Current node has exact coordinates of [5.767137012393951, 7.160057620279197, 61.53513980351937]
# Current node is in region coordinates of [2, 3, 2]
# Current node has exact coordinates of [7.701255516635899, 10.220763910599477, -1.1933129643662112e-14]
# Current node is in region coordinates of [3, 5, 1]
# Current node has exact coordinates of [10.376750067581968, 11.052974159744917, 36.92108388211167]
# Current node is in region coordinates of [5, 5, 1]
# Current node has exact coordinates of [12.658472432359114, 14.091681623466254, 36.92108388211167]
# Current node is in region coordinates of [6, 7, 1]
# Current node has exact coordinates of [14.94019479713626, 17.13038908718759, 36.92108388211167]
# Current node is in region coordinates of [7, 8, 1]
# Current node has exact coordinates of [17.221917161913385, 20.16909655090893, 36.92108388211167]
# Current node is in region coordinates of [8, 10, 1]
# Current node has exact coordinates of [19.503639526690495, 23.207804014630266, 36.92108388211167]
# Current node is in region coordinates of [9, 11, 1]
# Current node has exact coordinates of [9.10676684935391, 8.973031021100846, 61.53513980351937]
# Current node is in region coordinates of [4, 4, 2]
# Current node has exact coordinates of [12.947280024342323, 16.511518603385834, 12.307027960703921]
# Current node is in region coordinates of [6, 8, 0]
# Current node has exact coordinates of [15.229002389119469, 19.55022606710717, 12.307027960703921]
# Current node is in region coordinates of [7, 9, 0]
# Current node has exact coordinates of [17.510724753896607, 22.588933530828516, 12.307027960703921]
# Current node is in region coordinates of [8, 11, 0]
# Current node has exact coordinates of [9.468392529029849, 13.380821530878672, 61.53513980351937]
# Current node is in region coordinates of [4, 6, 2]
# Current node has exact coordinates of [14.901730524995365, 15.043949424242612, 61.53513980351937]
# Current node is in region coordinates of [7, 7, 2]
# Current node has exact coordinates of [17.18345288977251, 18.082656887963946, 61.53513980351937]
# Current node is in region coordinates of [8, 9, 2]
# Current node has exact coordinates of [19.465175254549642, 21.121364351685283, 61.53513980351937]
# Current node is in region coordinates of [9, 10, 2]
# Current node has exact coordinates of [5.222051150225931, 9.908461956214753, 24.614055921407758]
# Current node is in region coordinates of [2, 4, 0]
# Current node has exact coordinates of [8.792897321997899, 14.771834173035815, 49.228111842815466]
# Current node is in region coordinates of [4, 7, 1]
# Current node has exact coordinates of [12.467323957759014, 19.55742928756597, 24.614055921407754]
# Current node is in region coordinates of [6, 9, 0]
# Current node has exact coordinates of [6.8040132966038, 13.36351561244466, 24.614055921407758]
# Current node is in region coordinates of [3, 6, 0]
# Current node has exact coordinates of [11.669615268240065, 17.25467405062925, 49.228111842815466]
# Current node is in region coordinates of [5, 8, 1]
# Current node has exact coordinates of [11.040885353595861, 12.033737311421124, -1.1933129643662112e-14]
# Current node is in region coordinates of [5, 6, 1]
# Current node has exact coordinates of [4.0, 7.800000000000008, 0.0]
# Current node is in region coordinates of [2, 3, 0]
# Current node has exact coordinates of [15.347079041713823, 19.22255199681352, 73.84216776422329]
# Current node is in region coordinates of [7, 9, 2]
# Current node has exact coordinates of [17.62880140649097, 22.26125946053486, 73.84216776422329]
# Current node is in region coordinates of [8, 11, 2]
# Current node has exact coordinates of [16.038170129530982, 24.420801504387043, 49.228111842815466]
# Current node is in region coordinates of [8, 12, 1]
# Current node has exact coordinates of [15.400037518602648, 22.023987412926207, 36.92108388211167]
# Current node is in region coordinates of [7, 11, 1]
# Current node has exact coordinates of [10.374859468375769, 18.226887829265728, 49.228111842815466]
# Current node is in region coordinates of [5, 9, 1]
# Current node has exact coordinates of [15.34404190400118, 22.04026916515941, 24.614055921407754]
# Current node is in region coordinates of [7, 11, 0]
# Current node has exact coordinates of [13.71637990454193, 12.865947560566566, 36.92108388211167]
# Current node is in region coordinates of [6, 6, 1]
# Current node has exact coordinates of [16.835849029237313, 18.104655714562895, -1.1933129643662112e-14]
# Current node is in region coordinates of [8, 9, 1]
# Current node has exact coordinates of [15.998102269319075, 15.904655024287903, 36.92108388211167]
# Current node is in region coordinates of [7, 7, 1]
# Current node has exact coordinates of [19.11757139401446, 21.14336317828423, -1.1933129643662112e-14]
# Current node is in region coordinates of [9, 10, 1]
# Current node has exact coordinates of [18.279824634096187, 18.943362488009242, 36.92108388211167]
# Current node is in region coordinates of [9, 9, 1]
# Current node has exact coordinates of [20.561546998873297, 21.98206995173058, 36.92108388211167]
# Current node is in region coordinates of [10, 10, 1]
# Current node has exact coordinates of [14.546333214482232, 19.737513928222686, 49.228111842815466]
# Current node is in region coordinates of [7, 9, 1]
# Current node has exact coordinates of [8.385975442981668, 16.818569268674565, 24.614055921407758]
# Current node is in region coordinates of [4, 8, 0]
# Current node has exact coordinates of [13.251577414617936, 20.709727706859162, 49.228111842815466]
# Current node is in region coordinates of [6, 10, 1]
# Current node has exact coordinates of [18.220759850243347, 24.523109042752843, 24.614055921407754]
# Current node is in region coordinates of [9, 12, 0]
# Current node has exact coordinates of [11.956821614753638, 21.68194148549564, 49.228111842815466]
# Current node is in region coordinates of [5, 10, 1]
# Current node has exact coordinates of [16.92600405037905, 25.49532282138932, 24.614055921407754]
# Current node is in region coordinates of [8, 12, 0]
# Current node has exact coordinates of [17.4230511607244, 22.22035380581612, 49.228111842815466]
# Current node is in region coordinates of [8, 11, 1]
# Current node has exact coordinates of [13.756846607869083, 20.224280640850235, 12.307027960703921]
# Current node is in region coordinates of [6, 10, 0]
# Current node has exact coordinates of [15.631248250514753, 26.467536600025795, 24.614055921407754]
# Current node is in region coordinates of [7, 13, 0]
# Current node has exact coordinates of [16.286909861302284, 18.32449200420749, 12.307027960703921]
# Current node is in region coordinates of [8, 9, 0]
# Current node has exact coordinates of [18.568632226079423, 21.363199467928826, 12.307027960703921]
# Current node is in region coordinates of [9, 10, 0]
# Current node has exact coordinates of [12.446396686313882, 10.786004421922486, 61.53513980351937]
# Current node is in region coordinates of [6, 5, 2]
# Current node has exact coordinates of [14.833539560995805, 24.164781363089073, 49.228111842815466]
# Current node is in region coordinates of [7, 12, 1]
# Current node has exact coordinates of [9.967937589359536, 20.273622924904473, 24.614055921407758]
# Current node is in region coordinates of [4, 10, 0]
# Current node has exact coordinates of [12.808022365989814, 15.19379493170032, 61.53513980351937]
# Current node is in region coordinates of [6, 7, 2]
# Current node has exact coordinates of [5.767137012393951, 10.960057620279205, 61.53513980351937]
# Current node is in region coordinates of [2, 5, 2]
# Current node has exact coordinates of [17.88885990832972, 21.800940526527878, 12.307027960703914]
# Current node is in region coordinates of [8, 10, 0]
# Current node has exact coordinates of [13.538783761131507, 25.136995141725546, 49.228111842815466]
# Current node is in region coordinates of [6, 12, 1]
# Current node has exact coordinates of [18.241360361955337, 16.85692282506427, 61.53513980351937]
# Current node is in region coordinates of [9, 8, 2]
# Current node has exact coordinates of [20.523082726732483, 19.895630288785622, 61.53513980351937]
# Current node is in region coordinates of [10, 9, 2]
# Current node has exact coordinates of [17.710257507237973, 26.647621240682508, 49.228111842815466]
# Current node is in region coordinates of [8, 13, 1]
# Current node has exact coordinates of [10.030548959859331, 18.174326760442316, -12.307027960703913]
# Current node is in region coordinates of [5, 9, 0]
# Current node has exact coordinates of [10.86110841421243, 14.64102855957035, -24.61405592140771]
# Current node is in region coordinates of [5, 7, 0]
# Current node has exact coordinates of [15.42455314376672, 20.71844348701303, -24.61405592140771]
# Current node is in region coordinates of [7, 10, 0]
# Current node has exact coordinates of [15.389598887070989, 21.694962122769198, 86.14919572492714]
# Current node is in region coordinates of [7, 10, 2]
# Current node has exact coordinates of [9.726288225915773, 15.501048447647886, 86.14919572492714]
# Current node is in region coordinates of [4, 7, 2]
# Current node has exact coordinates of [11.549899735737405, 23.72867658113438, 24.614055921407758]
# Current node is in region coordinates of [5, 11, 0]
# Current node has exact coordinates of [13.6873254820965, 12.51886222125206, 98.45622368563104]
# Current node is in region coordinates of [6, 6, 3]
# Current node has exact coordinates of [15.969047846873645, 15.557569684973398, 98.45622368563104]
# Current node is in region coordinates of [7, 7, 3]
# Current node has exact coordinates of [18.250770211650792, 18.59627714869474, 98.45622368563104]
# Current node is in region coordinates of [9, 9, 3]
# Current node has exact coordinates of [20.53249257642792, 21.634984612416076, 98.45622368563104]
# Current node is in region coordinates of [10, 10, 3]
# Current node has exact coordinates of [18.266316833313155, 24.177802000362636, 86.14919572492714]
# Current node is in region coordinates of [9, 12, 2]
# Current node has exact coordinates of [14.380515190555833, 13.846710712242764, -1.1933129643662112e-14]
# Current node is in region coordinates of [7, 6, 1]
# Current node has exact coordinates of [15.120745907509376, 28.592048797955453, 49.228111842815466]
# Current node is in region coordinates of [7, 14, 1]
# Current node has exact coordinates of [11.308250372293642, 18.956102103877793, 86.14919572492714]
# Current node is in region coordinates of [5, 9, 2]
# Current node has exact coordinates of [11.612511106237202, 21.62938041667223, -12.307027960703913]
# Current node is in region coordinates of [5, 10, 0]
# Current node has exact coordinates of [10.376750067581968, 14.852974159744925, 36.92108388211167]
# Current node is in region coordinates of [5, 7, 1]
# Current node has exact coordinates of [12.658472432359114, 17.891681623466262, 36.92108388211167]
# Current node is in region coordinates of [6, 8, 1]
# Current node has exact coordinates of [14.94019479713626, 20.9303890871876, 36.92108388211167]
# Current node is in region coordinates of [7, 10, 1]
# Current node has exact coordinates of [7.701255516635899, 14.020763910599467, -1.1933129643662112e-14]
# Current node is in region coordinates of [3, 7, 1]
# Current node has exact coordinates of [20.175478866197285, 19.917629115384553, -1.1933129643662112e-14]
# Current node is in region coordinates of [10, 9, 1]
# Current node has exact coordinates of [17.056009741501907, 14.678920961388206, 36.92108388211167]
# Current node is in region coordinates of [8, 7, 1]
# Current node has exact coordinates of [14.489229052479368, 24.112220294265665, -12.307027960703913]
# Current node is in region coordinates of [7, 12, 0]
# Current node has exact coordinates of [19.337732106279017, 17.717628425109545, 36.92108388211167]
# Current node is in region coordinates of [9, 8, 1]
# Current node has exact coordinates of [13.131861882115274, 27.183730237364287, 24.614055921407758]
# Current node is in region coordinates of [6, 13, 0]
# Current node has exact coordinates of [14.064248867358943, 17.707167984891854, 73.84216776422316]
# Current node is in region coordinates of [7, 8, 2]
# Current node has exact coordinates of [12.890212518671511, 22.4111557601077, 86.14919572492714]
# Current node is in region coordinates of [6, 11, 2]
# Current node has exact coordinates of [13.19447325261507, 25.08443407290214, -12.307027960703913]
# Current node is in region coordinates of [6, 12, 0]
# Current node has exact coordinates of [22.85097341714335, 20.749839364529986, 36.92108388211167]
# Current node is in region coordinates of [11, 10, 1]
# Current node has exact coordinates of [16.94096681360111, 20.190007862485288, 73.84216776422316]
# Current node is in region coordinates of [8, 10, 2]
# Current node has exact coordinates of [16.07119119885724, 27.567273950495576, -12.307027960703913]
# Current node is in region coordinates of [8, 13, 0]
# Current node has exact coordinates of [16.147652202949786, 17.00676833252198, 61.53513980351937]
# Current node is in region coordinates of [8, 8, 2]
# Current node has exact coordinates of [15.786026523273854, 12.598977822744127, 61.53513980351937]
# Current node is in region coordinates of [7, 6, 2]
# Current node has exact coordinates of [14.713824028493143, 30.638783893594194, 24.614055921407758]
# Current node is in region coordinates of [7, 15, 0]
# Current node has exact coordinates of [14.47217466504938, 25.866209416337608, 86.14919572492714]
# Current node is in region coordinates of [7, 12, 2]
# Current node has exact coordinates of [8.15262141853996, 19.244381861157805, -4.7732518574648445e-15]
# Current node is in region coordinates of [4, 9, 1]
# Current node has exact coordinates of [14.20073825117239, 16.454001960392, -24.61405592140771]
# Current node is in region coordinates of [7, 8, 0]
# Current node has exact coordinates of [18.76418298072664, 22.53141688783468, -24.61405592140771]
# Current node is in region coordinates of [9, 11, 0]
# Current node has exact coordinates of [9.468392529029849, 17.18082153087866, 61.53513980351937]
# Current node is in region coordinates of [4, 8, 2]
# Current node has exact coordinates of [18.522928959978984, 23.6450615187152, 73.84216776422316]
# Current node is in region coordinates of [9, 11, 2]
# Current node has exact coordinates of [14.77643539899294, 28.53948772913205, -12.307027960703913]
# Current node is in region coordinates of [7, 14, 0]
# Current node has exact coordinates of [17.228173160114686, 24.617275297351675, 73.84216776422316]
# Current node is in region coordinates of [8, 12, 2]
# Current node has exact coordinates of [18.710612933117183, 23.489875474433354, 98.45622368563104]
# Current node is in region coordinates of [9, 11, 3]
# Current node has exact coordinates of [5.222051150225931, 13.708461956214757, 24.614055921407758]
# Current node is in region coordinates of [2, 6, 0]
# Current node has exact coordinates of [20.680229436848684, 22.044047799517895, 49.22811184281559]
# Current node is in region coordinates of [10, 11, 1]
# Current node has exact coordinates of [11.542827030636236, 8.904974957857684, 86.14919572492707]
# Current node is in region coordinates of [5, 4, 2]
# Current node has exact coordinates of [17.02695531905646, 14.33183562207371, 98.45622368563104]
# Current node is in region coordinates of [8, 7, 3]
# Current node has exact coordinates of [19.30867768383361, 17.370543085795052, 98.45622368563104]
# Current node is in region coordinates of [9, 8, 3]
# Current node has exact coordinates of [9.734583564917825, 22.699435517387712, -4.7732518574648445e-15]
# Current node is in region coordinates of [4, 11, 1]
# Current node has exact coordinates of [6.8040132966038, 17.163515612444662, 24.614055921407758]
# Current node is in region coordinates of [3, 8, 0]
# Current node has exact coordinates of [4.0, 11.6, 0.0]
# Current node is in region coordinates of [2, 5, 0]
# Current node has exact coordinates of [10.374859468375769, 22.026887829265736, 49.228111842815466]
# Current node is in region coordinates of [5, 11, 1]
# Current node has exact coordinates of [9.919758430933912, 22.404439481437006, 61.53513980351937]
# Current node is in region coordinates of [4, 11, 2]
# Current node has exact coordinates of [20.395639578461868, 16.491894362209845, 36.92108388211167]
# Current node is in region coordinates of [10, 8, 1]
# Current node has exact coordinates of [15.542566463852355, 27.576208989665716, 49.228111842815466]
# Current node is in region coordinates of [7, 13, 1]
# Current node has exact coordinates of [22.677361943238978, 19.530601825931182, 36.92108388211167]
# Current node is in region coordinates of [11, 9, 1]
# Current node has exact coordinates of [11.316545711295694, 26.15448917361762, -4.7732518574648445e-15]
# Current node is in region coordinates of [5, 13, 1]
# Current node has exact coordinates of [12.808022365989821, 18.993794931700336, 61.53513980351937]
# Current node is in region coordinates of [6, 9, 2]
# Current node has exact coordinates of [19.487282039909758, 18.819741733343655, 61.53513980351937]
# Current node is in region coordinates of [9, 9, 2]
# Current node has exact coordinates of [12.339769088039883, 15.498771625167334, 110.76325164633485]
# Current node is in region coordinates of [6, 7, 3]
# Current node has exact coordinates of [11.501720577311778, 25.859493137666913, 61.53513980351937]
# Current node is in region coordinates of [5, 12, 2]
# Current node has exact coordinates of [4.930877029153224, 13.517333665665614, -36.921083882111624]
# Current node is in region coordinates of [2, 6, 10]
# Current node has exact coordinates of [19.125656360233826, 14.411951223565767, 61.53513980351937]
# Current node is in region coordinates of [9, 7, 2]
# Current node has exact coordinates of [5.767137012393951, 14.760057620279195, 61.53513980351937]
# Current node is in region coordinates of [2, 7, 2]
# Current node has exact coordinates of [13.6873254820965, 16.31886222125207, 98.45622368563104]
# Current node is in region coordinates of [6, 8, 3]
# Current node has exact coordinates of [15.969047846873645, 19.35756968497341, 98.45622368563104]
# Current node is in region coordinates of [7, 9, 3]
# Current node has exact coordinates of [12.898507857673563, 29.609542829847527, -4.7732518574648445e-15]
# Current node is in region coordinates of [6, 14, 1]
# Current node has exact coordinates of [13.921731234417754, 18.953825281397247, 110.76325164633485]
# Current node is in region coordinates of [6, 9, 3]
# Current node has exact coordinates of [13.012045351024474, 22.544688346917454, -12.307027960703836]
# Current node is in region coordinates of [6, 11, 0]
# Current node has exact coordinates of [11.853876935175862, 25.46514577175729, -1.1933129643662112e-14]
# Current node is in region coordinates of [5, 12, 1]
# Current node has exact coordinates of [15.21648703428205, 17.981611502760774, 110.76325164633485]
# Current node is in region coordinates of [7, 8, 3]
# Current node has exact coordinates of [9.726288225915773, 19.30104844764789, 86.14919572492714]
# Current node is in region coordinates of [4, 9, 2]
# Current node has exact coordinates of [12.176149836686307, 23.16630099701684, -36.921083882111624]
# Current node is in region coordinates of [6, 11, 10]
# Current node has exact coordinates of [8.923306666861826, 19.92922586681422, 24.614055921407747]
# Current node is in region coordinates of [4, 9, 0]
# Current node has exact coordinates of [13.259388267893884, 24.21741288225868, 61.53513980351937]
# Current node is in region coordinates of [6, 12, 2]
# Current node has exact coordinates of [6.512839175531092, 16.972387321895518, -36.921083882111624]
# Current node is in region coordinates of [3, 8, 10]
# Current node has exact coordinates of [14.882456867596193, 10.717948358679333, 86.14919572492707]
# Current node is in region coordinates of [7, 5, 2]
# Current node has exact coordinates of [9.387451516150467, 7.114667335553626, 123.07027960703874]
# Current node is in region coordinates of [4, 3, 4]
# Current node has exact coordinates of [13.083682723689646, 29.31454679389682, 61.53513980351937]
# Current node is in region coordinates of [6, 14, 2]
# Current node has exact coordinates of [17.071773463464773, 13.805038432145986, 36.92108388211167]
# Current node is in region coordinates of [8, 6, 1]
# Current node has exact coordinates of [16.79844918065992, 21.43666515899068, 110.76325164633485]
# Current node is in region coordinates of [8, 10, 3]
# Current node has exact coordinates of [15.503693380795623, 22.40887893762716, 110.76325164633485]
# Current node is in region coordinates of [7, 11, 3]
# Current node has exact coordinates of [15.052867782928473, 25.64914087461028, -36.921083882111624]
# Current node is in region coordinates of [7, 12, 10]
# Current node has exact coordinates of [14.575565110144217, 10.882659746988516, 24.61405592140769]
# Current node is in region coordinates of [7, 5, 0]
# Current node has exact coordinates of [18.093204980524213, 20.46445138035421, 110.76325164633485]
# Current node is in region coordinates of [9, 10, 3]
# Current node has exact coordinates of [20.36658515601644, 16.14480902289535, 98.45622368563104]
# Current node is in region coordinates of [10, 8, 3]
# Current node has exact coordinates of [22.64830752079355, 19.183516486616693, 98.45622368563104]
# Current node is in region coordinates of [11, 9, 3]
# Current node has exact coordinates of [14.480470004051432, 33.064596486077434, -4.7732518574648445e-15]
# Current node is in region coordinates of [7, 16, 1]
# Current node has exact coordinates of [18.14641128191618, 15.746031963809585, 49.22811184281541]
# Current node is in region coordinates of [9, 7, 1]
# Current node has exact coordinates of [16.157527256522084, 14.337713403218423, 24.61405592140769]
# Current node is in region coordinates of [8, 7, 0]
# Current node has exact coordinates of [20.67742054323765, 16.7888667618211, 86.14919572492707]
# Current node is in region coordinates of [10, 8, 2]
# Current node has exact coordinates of [18.380411327037788, 24.891718815220596, 110.76325164633485]
# Current node is in region coordinates of [9, 12, 3]
# Current node has exact coordinates of [7.701255516635899, 17.820763910599474, -1.1933129643662112e-14]
# Current node is in region coordinates of [3, 8, 1]
# Current node has exact coordinates of [22.9591429080148, 19.82757422554244, 86.14919572492707]
# Current node is in region coordinates of [11, 9, 2]
# Current node has exact coordinates of [11.612511106237202, 25.429380416672238, -12.307027960703913]
# Current node is in region coordinates of [5, 12, 0]
# Current node has exact coordinates of [17.08565552717349, 25.86393259385707, 110.76325164633485]
# Current node is in region coordinates of [8, 12, 3]
# Current node has exact coordinates of [14.84135041427175, 27.67246653848859, 61.53513980351937]
# Current node is in region coordinates of [7, 13, 2]
# Current node has exact coordinates of [8.09480132190896, 20.427440978125436, -36.921083882111624]
# Current node is in region coordinates of [4, 10, 10]
# Current node has exact coordinates of [19.64230342022512, 19.263582875786906, 12.307027960703921]
# Current node is in region coordinates of [9, 9, 0]
# Current node has exact coordinates of [21.82083791767729, 20.531627078339746, 24.61405592140769]
# Current node is in region coordinates of [10, 10, 0]
# Current node has exact coordinates of [17.739489402899917, 17.79276705944833, 24.61405592140769]
# Current node is in region coordinates of [8, 8, 0]
# Current node has exact coordinates of [14.665644870067515, 32.76960045012673, 61.53513980351937]
# Current node is in region coordinates of [7, 16, 2]
# Current node has exact coordinates of [6.570659272162092, 19.589328204927902, -4.7732518574648445e-15]
# Current node is in region coordinates of [3, 9, 1]
# Current node has exact coordinates of [2.777948849774069, 9.908461956214753, -24.614055921407758]
# Current node is in region coordinates of [1, 4, 0]
# Current node has exact coordinates of [15.340074129442046, 30.076408309476665, -36.921083882111624]
# Current node is in region coordinates of [7, 15, 10]
# Current node has exact coordinates of [20.590170382015987, 21.249872625683068, 73.84216776422316]
# Current node is in region coordinates of [10, 10, 2]
# Current node has exact coordinates of [22.82691187686973, 20.63271513416533, 61.53513980351937]
# Current node is in region coordinates of [11, 10, 2]
# Current node has exact coordinates of [9.374672568765888, 25.15284381737256, 24.614055921407758]
# Current node is in region coordinates of [4, 12, 0]
# Current node has exact coordinates of [9.676763468286829, 23.882494634355343, -36.921083882111624]
# Current node is in region coordinates of [4, 11, 10]
# Current node has exact coordinates of [11.8455815961738, 22.06675870201745, 86.14919572492713]
# Current node is in region coordinates of [5, 11, 2]
# Current node has exact coordinates of [11.542827030636236, 12.704974957857692, 86.14919572492707]
# Current node is in region coordinates of [5, 6, 2]
# Current node has exact coordinates of [16.599018104853855, 26.030386283080357, 61.53513980351937]
# Current node is in region coordinates of [8, 13, 2]
# Current node has exact coordinates of [12.945518740537858, 30.016216034193633, 49.228111842815466]
# Current node is in region coordinates of [6, 15, 1]
# Current node has exact coordinates of [9.468392529029849, 20.980821530878675, 61.53513980351937]
# Current node is in region coordinates of [4, 10, 2]
# Current node has exact coordinates of [11.893942612969337, 19.975507298785885, -49.22811184281545]
# Current node is in region coordinates of [5, 9, 10]
# Current node has exact coordinates of [14.175664977746482, 23.014214762507223, -49.22811184281545]
# Current node is in region coordinates of [7, 11, 10]
# Current node has exact coordinates of [16.45738734252362, 26.052922226228567, -49.22811184281545]
# Current node is in region coordinates of [8, 13, 10]
# Current node has exact coordinates of [22.465286197193798, 16.224924624387413, 61.53513980351937]
# Current node is in region coordinates of [11, 8, 2]
# Current node has exact coordinates of [13.088707032786365, 13.3354312461531, 123.07027960703874]
# Current node is in region coordinates of [6, 6, 4]
# Current node has exact coordinates of [5.222051150225931, 17.50846195621475, 24.614055921407758]
# Current node is in region coordinates of [2, 8, 0]
# Current node has exact coordinates of [12.727081353110426, 8.927640736375274, 123.07027960703874]
# Current node is in region coordinates of [6, 4, 4]
# Current node has exact coordinates of [11.258725614664698, 27.33754829058525, -36.921083882111624]
# Current node is in region coordinates of [5, 13, 10]
# Current node has exact coordinates of [20.45187000375188, 22.976344913251307, 12.307027960703921]
# Current node is in region coordinates of [10, 11, 0]
# Current node has exact coordinates of [10.956634715143753, 28.607897473602467, 24.614055921407758]
# Current node is in region coordinates of [5, 14, 0]
# Current node has exact coordinates of [17.497840039456186, 13.020192582191742, 86.14919572492707]
# Current node is in region coordinates of [8, 6, 2]
# Current node has exact coordinates of [2.2328629876060466, 7.160057620279197, -61.53513980351937]
# Current node is in region coordinates of [1, 3, 9]
# Current node has exact coordinates of [18.222086704556165, 12.530921759500973, 86.14919572492707]
# Current node is in region coordinates of [9, 6, 2]
# Current node has exact coordinates of [20.411403300424737, 15.618011832967635, 36.92108388211167]
# Current node is in region coordinates of [10, 7, 1]
# Current node has exact coordinates of [17.91519494710418, 12.695633147810165, 24.61405592140769]
# Current node is in region coordinates of [8, 6, 0]
# Current node has exact coordinates of [18.522045028751876, 14.99855913951704, 123.07027960703874]
# Current node is in region coordinates of [9, 7, 4]
# Current node has exact coordinates of [20.80376739352902, 18.037266603238372, 123.07027960703874]
# Current node is in region coordinates of [10, 9, 4]
# Current node has exact coordinates of [19.497157093482013, 16.15068680404007, 24.61405592140769]
# Current node is in region coordinates of [9, 8, 0]
# Current node has exact coordinates of [23.706214992976403, 17.957782423716992, 98.45622368563104]
# Current node is in region coordinates of [11, 8, 3]
# Current node has exact coordinates of [4.0, 15.39999999999999, 0.0]
# Current node is in region coordinates of [2, 7, 0]
# Current node has exact coordinates of [12.296947498077863, 27.290376652575787, 86.14919572492714]
# Current node is in region coordinates of [6, 13, 2]
# Current node has exact coordinates of [9.734583564917825, 26.499435517387738, -4.7732518574648445e-15]
# Current node is in region coordinates of [4, 13, 1]
# Current node has exact coordinates of [6.8040132966038, 20.963515612444656, 24.614055921407758]
# Current node is in region coordinates of [3, 10, 0]
# Current node has exact coordinates of [21.079119239859846, 19.605740460269978, 24.61405592140769]
# Current node is in region coordinates of [10, 9, 0]
# Current node has exact coordinates of [24.017050380197627, 18.601840162642763, 86.14919572492707]
# Current node is in region coordinates of [12, 9, 2]
# Current node has exact coordinates of [12.840687761042567, 30.792601946815157, -36.921083882111624]
# Current node is in region coordinates of [6, 15, 10]
# Current node has exact coordinates of [23.71015862274563, 18.766551550951938, 24.61405592140769]
# Current node is in region coordinates of [11, 9, 0]
# Current node has exact coordinates of [12.538596861521622, 32.06295112983238, 24.614055921407758]
# Current node is in region coordinates of [6, 16, 0]
# Current node has exact coordinates of [15.2335724499293, 21.78848069960754, -49.22811184281545]
# Current node is in region coordinates of [7, 10, 10]
# Current node has exact coordinates of [17.515294814706436, 24.827188163328877, -49.22811184281545]
# Current node is in region coordinates of [8, 12, 10]
# Current node has exact coordinates of [17.071773463464773, 17.605038432145996, 36.92108388211167]
# Current node is in region coordinates of [8, 8, 1]
# Current node has exact coordinates of [13.878909644455728, 30.745430308805695, 86.14919572492714]
# Current node is in region coordinates of [6, 15, 2]
# Current node has exact coordinates of [14.575565110144217, 14.682659746988524, 24.61405592140769]
# Current node is in region coordinates of [7, 7, 0]
# Current node has exact coordinates of [11.316545711295694, 29.954489173617645, -4.7732518574648445e-15]
# Current node is in region coordinates of [5, 14, 1]
# Current node has exact coordinates of [13.921731234417754, 22.75382528139726, 110.76325164633485]
# Current node is in region coordinates of [6, 11, 3]
# Current node has exact coordinates of [9.387451516150467, 10.914667335553633, 123.07027960703874]
# Current node is in region coordinates of [4, 5, 4]
# Current node has exact coordinates of [4.930877029153224, 17.31733366566562, -36.921083882111624]
# Current node is in region coordinates of [2, 8, 10]
# Current node has exact coordinates of [11.54774577955505, 27.66255016020385, 12.307027960703842]
# Current node is in region coordinates of [5, 13, 0]
# Current node has exact coordinates of [13.075928085401788, 31.373607727972043, 24.614055921407747]
# Current node is in region coordinates of [6, 15, 0]
# Current node has exact coordinates of [20.382348877979307, 15.27092649365313, 98.45622368563104]
# Current node is in region coordinates of [10, 7, 3]
# Current node has exact coordinates of [5.767137012393951, 18.560057620279185, 61.53513980351937]
# Current node is in region coordinates of [2, 9, 2]
# Current node has exact coordinates of [14.183170378399291, 33.418708621600125, -12.307027960703913]
# Current node is in region coordinates of [7, 16, 0]
# Current node has exact coordinates of [16.428336869746328, 15.148404646974747, 123.07027960703874]
# Current node is in region coordinates of [8, 7, 4]
# Current node has exact coordinates of [14.120559007899491, 35.51800478606228, 24.614055921407758]
# Current node is in region coordinates of [7, 17, 0]
# Current node has exact coordinates of [11.501720577311778, 29.65949313766694, 61.53513980351937]
# Current node is in region coordinates of [5, 14, 2]
# Current node has exact coordinates of [16.0667111900704, 10.740614137196914, 123.07027960703874]
# Current node is in region coordinates of [8, 5, 4]
# Current node has exact coordinates of [12.384906669088311, 28.797196110366542, -12.307027960703913]
# Current node is in region coordinates of [6, 14, 0]
# Current node has exact coordinates of [5.9341185042419475, 13.38082153087867, -61.53513980351938]
# Current node is in region coordinates of [2, 6, 9]
# Current node has exact coordinates of [8.923306666861826, 23.72922586681423, 24.614055921407747]
# Current node is in region coordinates of [4, 11, 0]
# Current node has exact coordinates of [6.512839175531092, 20.772387321895533, -36.921083882111624]
# Current node is in region coordinates of [3, 10, 10]
# Current node has exact coordinates of [20.83746987641615, 14.83316598301339, 86.14919572492707]
# Current node is in region coordinates of [10, 7, 2]
# Current node has exact coordinates of [12.898507857673563, 33.409542829847524, -4.7732518574648445e-15]
# Current node is in region coordinates of [6, 16, 1]
# Current node has exact coordinates of [20.53057811896417, 14.997877371322573, 24.61405592140769]
# Current node is in region coordinates of [10, 7, 0]
# Current node has exact coordinates of [23.75103313738472, 17.430985233789276, 36.92108388211167]
# Current node is in region coordinates of [11, 8, 1]
# Current node has exact coordinates of [21.861674865711848, 16.811532540338696, 123.07027960703874]
# Current node is in region coordinates of [10, 8, 4]
# Current node has exact coordinates of [13.083682723689646, 33.11454679389686, 61.53513980351937]
# Current node is in region coordinates of [6, 16, 2]
# Current node has exact coordinates of [7.701255516635899, 21.6207639105995, -1.1933129643662112e-14]
# Current node is in region coordinates of [3, 10, 1]
# Current node has exact coordinates of [14.84135041427175, 31.472466538488614, 61.53513980351937]
# Current node is in region coordinates of [7, 15, 2]
# Current node has exact coordinates of [14.284390989071506, 14.491531456439375, -36.92108388211169]
# Current node is in region coordinates of [7, 7, 10]
# Current node has exact coordinates of [11.542827030636236, 16.504974957857684, 86.14919572492707]
# Current node is in region coordinates of [5, 8, 2]
# Current node has exact coordinates of [15.334052180934332, 9.163067692639709, 86.14919572492707]
# Current node is in region coordinates of [7, 4, 2]
# Current node has exact coordinates of [3.0691229708467755, 13.517333665665614, 36.921083882111624]
# Current node is in region coordinates of [1, 6, 1]
# Current node has exact coordinates of [5.350845335623921, 16.55604112938695, 36.921083882111624]
# Current node is in region coordinates of [2, 8, 1]
# Current node has exact coordinates of [7.792710422388024, 25.497790161142657, 24.614055921407758]
# Current node is in region coordinates of [3, 12, 0]
# Current node has exact coordinates of [10.723280690702046, 31.033710066085707, -4.7732518574648445e-15]
# Current node is in region coordinates of [5, 15, 1]
# Current node has exact coordinates of [17.354644673945575, 10.525501842153, 61.53513980351937]
# Current node is in region coordinates of [8, 5, 2]
# Current node has exact coordinates of [2.777948849774069, 13.708461956214757, -24.614055921407758]
# Current node is in region coordinates of [1, 6, 0]
# Current node has exact coordinates of [21.361918359453842, 19.69693547415477, 98.45622368563099]
# Current node is in region coordinates of [10, 9, 3]
# Current node has exact coordinates of [14.480470004051432, 36.86459648607739, -4.7732518574648445e-15]
# Current node is in region coordinates of [7, 18, 1]
# Current node has exact coordinates of [15.866353135449375, 17.946585112669283, -36.92108388211169]
# Current node is in region coordinates of [7, 8, 10]
# Current node has exact coordinates of [13.088707032786365, 17.135431246153086, 123.07027960703874]
# Current node is in region coordinates of [6, 8, 4]
# Current node has exact coordinates of [6.570659272162092, 23.389328204927928, -4.7732518574648445e-15]
# Current node is in region coordinates of [3, 11, 1]
# Current node has exact coordinates of [7.594103428260166, 17.50830893016331, 61.53513980351933]
# Current node is in region coordinates of [3, 8, 2]
# Current node has exact coordinates of [9.273748341201907, 15.193794931700317, -61.53513980351938]
# Current node is in region coordinates of [4, 7, 9]
# Current node has exact coordinates of [17.44831528182721, 21.401638768899197, -36.92108388211169]
# Current node is in region coordinates of [8, 10, 10]
# Current node has exact coordinates of [14.665644870067515, 36.569600450126714, 61.53513980351937]
# Current node is in region coordinates of [7, 18, 2]
# Current node has exact coordinates of [15.068712016843365, 21.264713334842092, -61.53513980351938]
# Current node is in region coordinates of [7, 10, 9]
# Current node has exact coordinates of [17.35043438162051, 24.30342079856343, -61.53513980351938]
# Current node is in region coordinates of [8, 12, 9]
# Current node has exact coordinates of [19.767966706706297, 16.961378047796405, 123.07027960703874]
# Current node is in region coordinates of [9, 8, 4]
# Current node has exact coordinates of [9.374672568765892, 28.952843817372564, 24.614055921407758]
# Current node is in region coordinates of [4, 14, 0]
# Current node has exact coordinates of [9.468392529029849, 24.7808215308787, 61.53513980351937]
# Current node is in region coordinates of [4, 12, 2]
# Current node has exact coordinates of [19.288763178187523, 13.586208132473278, -1.1933129643662112e-14]
# Current node is in region coordinates of [9, 6, 1]
# Current node has exact coordinates of [13.540072934690428, 22.35904919671143, 123.07027960703874]
# Current node is in region coordinates of [6, 11, 4]
# Current node has exact coordinates of [2.2328629876060466, 10.960057620279205, -61.53513980351937]
# Current node is in region coordinates of [1, 5, 9]
# Current node has exact coordinates of [18.874610566844968, 18.406918057314208, 135.37730756774266]
# Current node is in region coordinates of [9, 9, 4]
# Current node has exact coordinates of [21.156332931622117, 21.445625521035545, 135.37730756774266]
# Current node is in region coordinates of [10, 10, 4]
# Current node has exact coordinates of [12.305242837079911, 34.48876372231561, -4.7732518574648445e-15]
# Current node is in region coordinates of [6, 17, 1]
# Current node has exact coordinates of [5.6396529276071234, 18.97587810930654, 12.307027960703877]
# Current node is in region coordinates of [2, 9, 0]
# Current node has exact coordinates of [19.406341027030365, 12.553587538018554, 123.07027960703874]
# Current node is in region coordinates of [9, 6, 4]
# Current node has exact coordinates of [7.921375292384269, 22.01458557302788, 12.307027960703877]
# Current node is in region coordinates of [3, 11, 0]
# Current node has exact coordinates of [10.714985351699998, 27.635322996345884, 86.14919572492714]
# Current node is in region coordinates of [5, 13, 2]
# Current node has exact coordinates of [5.222051150225931, 21.308461956214746, 24.614055921407758]
# Current node is in region coordinates of [2, 10, 0]
# Current node has exact coordinates of [17.44649918394849, 11.963332672709033, 98.45622368563104]
# Current node is in region coordinates of [8, 5, 3]
# Current node has exact coordinates of [19.728221548725635, 15.00204013643037, 98.45622368563104]
# Current node is in region coordinates of [9, 7, 3]
# Current node has exact coordinates of [12.490417703095998, 34.19376768636491, 61.53513980351937]
# Current node is in region coordinates of [6, 17, 2]
# Current node has exact coordinates of [15.122035081068294, 25.81410285294134, 123.07027960703874]
# Current node is in region coordinates of [7, 12, 4]
# Current node has exact coordinates of [23.870207955924133, 16.810850772144224, 24.61405592140769]
# Current node is in region coordinates of [11, 8, 0]
# Current node has exact coordinates of [24.901346378476116, 16.156868561144254, 86.14919572492707]
# Current node is in region coordinates of [12, 8, 2]
# Current node has exact coordinates of [8.337796284556045, 26.54938582520713, 61.53513980351937]
# Current node is in region coordinates of [4, 13, 2]
# Current node has exact coordinates of [17.624020826031472, 16.304504857261026, -36.92108388211169]
# Current node is in region coordinates of [8, 8, 10]
# Current node has exact coordinates of [10.956634715143753, 32.40789747360249, 24.614055921407758]
# Current node is in region coordinates of [5, 16, 0]
# Current node has exact coordinates of [15.244082547272132, 22.725738868457167, 86.14919572492707]
# Current node is in region coordinates of [7, 11, 2]
# Current node has exact coordinates of [16.428336869746335, 18.948404646974762, 123.07027960703874]
# Current node is in region coordinates of [8, 9, 4]
# Current node has exact coordinates of [9.387451516150467, 14.714667335553623, 123.07027960703874]
# Current node is in region coordinates of [4, 7, 4]
# Current node has exact coordinates of [19.205982972409306, 19.759558513490937, -36.92108388211169]
# Current node is in region coordinates of [9, 9, 10]
# Current node has exact coordinates of [13.88720498345778, 37.94381737854552, -4.7732518574648445e-15]
# Current node is in region coordinates of [6, 18, 1]
# Current node has exact coordinates of [12.613378178161879, 17.00676833252196, -61.53513980351938]
# Current node is in region coordinates of [6, 8, 9]
# Current node has exact coordinates of [18.673682017894265, 10.976041093461358, 86.14919572492707]
# Current node is in region coordinates of [9, 5, 2]
# Current node has exact coordinates of [9.734583564917825, 30.299435517387764, -4.7732518574648445e-15]
# Current node is in region coordinates of [4, 15, 1]
# Current node has exact coordinates of [18.366790260442315, 11.14075248177054, 24.61405592140769]
# Current node is in region coordinates of [9, 5, 0]
# Current node has exact coordinates of [18.408341853803336, 23.077686735663754, -61.53513980351938]
# Current node is in region coordinates of [9, 11, 9]
# Current node has exact coordinates of [6.479204366409967, 19.92922586681422, -24.614055921407772]
# Current node is in region coordinates of [3, 9, 0]
# Current node has exact coordinates of [20.694274510905537, 12.33847524297465, 61.53513980351937]
# Current node is in region coordinates of [10, 6, 2]
# Current node has exact coordinates of [19.948752406820148, 14.595806138000448, 24.61405592140769]
# Current node is in region coordinates of [9, 7, 0]
# Current node has exact coordinates of [9.08349844769318, 28.76171552682343, -36.921083882111624]
# Current node is in region coordinates of [4, 14, 10]
# Current node has exact coordinates of [16.879702771650397, 24.172022597533108, 123.07027960703874]
# Current node is in region coordinates of [8, 12, 4]
# Current node has exact coordinates of [8.092410421867442, 24.48834691884691, 36.921083882111624]
# Current node is in region coordinates of [4, 12, 1]
# Current node has exact coordinates of [6.379698385361308, 14.98322172717276, 98.45622368563099]
# Current node is in region coordinates of [3, 7, 3]
# Current node has exact coordinates of [8.661420750138452, 18.0219291908941, 98.45622368563099]
# Current node is in region coordinates of [4, 9, 3]
# Current node has exact coordinates of [12.538596861521622, 35.862951129832396, 24.614055921407758]
# Current node is in region coordinates of [6, 17, 0]
# Current node has exact coordinates of [23.10759654366627, 18.77435144861808, 123.07027960703874]
# Current node is in region coordinates of [11, 9, 4]
# Current node has exact coordinates of [4.930877029153224, 21.11733366566562, -36.921083882111624]
# Current node is in region coordinates of [2, 10, 10]
# Current node has exact coordinates of [22.95580613134113, 20.66439133982656, 98.45622368563086]
# Current node is in region coordinates of [11, 10, 3]
# Current node has exact coordinates of [9.192405121656371, 27.470549034180785, 24.614055921407758]
# Current node is in region coordinates of [4, 13, 0]
# Current node has exact coordinates of [17.354644673945575, 14.325501842153008, 61.53513980351937]
# Current node is in region coordinates of [8, 7, 2]
# Current node has exact coordinates of [18.588966008852132, 22.727571571186957, -49.22811184281545]
# Current node is in region coordinates of [9, 11, 10]
# Current node has exact coordinates of [5.9341185042419475, 17.18082153087866, -61.53513980351938]
# Current node is in region coordinates of [2, 8, 9]
# Current node has exact coordinates of [11.54774577955505, 31.462550160203858, 12.307027960703842]
# Current node is in region coordinates of [5, 15, 0]
# Current node has exact coordinates of [17.59178039249009, 16.891534045392547, 135.37730756774255]
# Current node is in region coordinates of [8, 8, 4]
# Current node has exact coordinates of [11.316545711295694, 33.754489173617635, -4.7732518574648445e-15]
# Current node is in region coordinates of [5, 16, 1]
# Current node has exact coordinates of [22.628393015147484, 15.399181533294927, -1.1933129643662112e-14]
# Current node is in region coordinates of [11, 7, 1]
# Current node has exact coordinates of [14.284390989071506, 18.291531456439387, -36.92108388211169]
# Current node is in region coordinates of [7, 9, 10]
# Current node has exact coordinates of [10.665460594071046, 32.216769183053344, -36.921083882111624]
# Current node is in region coordinates of [5, 16, 10]
# Current node has exact coordinates of [3.5534813174772326, 17.10538806549105, -24.614055921407758]
# Current node is in region coordinates of [1, 8, 0]
# Current node has exact coordinates of [22.745970863990337, 14.366560938840195, 123.07027960703874]
# Current node is in region coordinates of [11, 7, 4]
# Current node has exact coordinates of [20.78612902090845, 13.776306073530682, 98.45622368563104]
# Current node is in region coordinates of [10, 6, 3]
# Current node has exact coordinates of [11.501720577311778, 33.459493137666975, 61.53513980351937]
# Current node is in region coordinates of [5, 16, 2]
# Current node has exact coordinates of [11.542827030636236, 20.304974957857677, 86.14919572492707]
# Current node is in region coordinates of [5, 10, 2]
# Current node has exact coordinates of [6.512839175531092, 24.572387321895526, -36.921083882111624]
# Current node is in region coordinates of [3, 12, 10]
# Current node has exact coordinates of [20.23940399789146, 18.60674908077344, -36.92108388211169]
# Current node is in region coordinates of [10, 9, 10]
# Current node has exact coordinates of [13.088707032786365, 20.9354312461531, 123.07027960703874]
# Current node is in region coordinates of [6, 10, 4]
# Current node has exact coordinates of [25.30388756609355, 16.23139178244037, 36.92108388211167]
# Current node is in region coordinates of [12, 8, 1]
# Current node has exact coordinates of [7.701255516635899, 25.420763910599526, -1.1933129643662112e-14]
# Current node is in region coordinates of [3, 12, 1]
# Current node has exact coordinates of [3.0691229708467755, 17.31733366566562, 36.921083882111624]
# Current node is in region coordinates of [1, 8, 1]
# Current node has exact coordinates of [13.000117687611583, 6.875125026894519, 61.53513980351936]
# Current node is in region coordinates of [6, 3, 2]
# Current node has exact coordinates of [5.350845335623921, 20.356041129386956, 36.921083882111624]
# Current node is in region coordinates of [2, 10, 1]
# Current node has exact coordinates of [12.247422740448915, 35.67182283928321, -36.921083882111624]
# Current node is in region coordinates of [6, 17, 10]
# Current node has exact coordinates of [22.013311854854226, 12.789014494282998, 86.14919572492707]
# Current node is in region coordinates of [11, 6, 2]
# Current node has exact coordinates of [14.84135041427175, 35.27246653848865, 61.53513980351937]
# Current node is in region coordinates of [7, 17, 2]
# Current node has exact coordinates of [6.38548440614601, 22.404439481437006, -61.53513980351938]
# Current node is in region coordinates of [3, 11, 9]
# Current node has exact coordinates of [21.706420097402248, 12.95372588259219, 24.61405592140769]
# Current node is in region coordinates of [10, 6, 0]
# Current node has exact coordinates of [23.30965768276553, 14.640719466487058, 61.53513980351937]
# ...
# Current node is in region coordinates of [9, 5, 6]
# Current node has exact coordinates of [54.78267980673953, 89.5647837389332, 49.228111842815466]
# Current node is in region coordinates of [27, 44, 1]
# Current node has exact coordinates of [1.6145155938539975, 26.20443948143703, 61.53513980351938]
# Current node is in region coordinates of [0, 13, 2]
# Current node has exact coordinates of [45.33550454126347, 80.18146681494254, 12.307027960703788]
# Current node is in region coordinates of [22, 40, 0]
# Current node has exact coordinates of [62.51046380099327, 92.8387734759001, 49.228111842815466]
# Current node is in region coordinates of [31, 46, 1]
# Current node has exact coordinates of [64.90509740011215, 93.2912674101626, 73.84216776422316]
# Current node is in region coordinates of [32, 46, 2]
# Current node has exact coordinates of [-0.33779628455604116, 22.749385825207103, -61.53513980351937]
# Current node is in region coordinates of [99, 11, 9]
# Current node has exact coordinates of [48.212222487505635, 82.66430669253604, 12.307027960703788]
# Current node is in region coordinates of [24, 41, 0]
# Current node has exact coordinates of [38.32008081880549, 76.9704997103088, 24.614055921407754]
# Current node is in region coordinates of [19, 38, 0]
# Current node has exact coordinates of [57.949799028031045, 88.59430255879991, 73.84216776422316]
# Current node is in region coordinates of [28, 44, 2]
# Current node has exact coordinates of [16.928828583376927, 20.072637142280588, -98.45622368563106]
# Current node is in region coordinates of [8, 10, 8]
# Current node has exact coordinates of [60.05403135210057, 92.50011755078921, 73.84216776422316]
# Current node is in region coordinates of [30, 46, 2]
# Current node has exact coordinates of [67.78181534635434, 95.77410728775611, 73.84216776422316]
# Current node is in region coordinates of [33, 47, 2]
# Current node has exact coordinates of [26.858766016906614, 66.6938331575445, 86.14919572492714]
# Current node is in region coordinates of [13, 33, 2]
# Current node has exact coordinates of [60.82651697427321, 91.07714243639342, 73.84216776422316]
# Current node is in region coordinates of [30, 45, 2]
# Current node has exact coordinates of [51.0889404337478, 85.14714657012955, 12.307027960703788]
# Current node is in region coordinates of [25, 42, 0]
# Current node has exact coordinates of [8.950357657523398, 38.1725499321007, 98.45622368563099]
# Current node is in region coordinates of [4, 19, 3]
# Current node has exact coordinates of [24.523071667385288, 64.70404809940779, 36.92108388211167]
# Current node is in region coordinates of [12, 32, 1]
# Current node has exact coordinates of [21.844026598211364, 63.22575886404098, 49.228111842815466]
# Current node is in region coordinates of [10, 31, 1]
# Current node has exact coordinates of [41.19679876504766, 79.4533395879023, 24.614055921407754]
# Current node is in region coordinates of [20, 39, 0]
# Current node has exact coordinates of [29.73548396314878, 69.17667303513801, 86.14919572492714]
# Current node is in region coordinates of [14, 34, 2]
# Current node has exact coordinates of [18.000612228095974, 5.634775212534085, 86.14919572492707]
# Current node is in region coordinates of [9, 2, 2]
# Current node has exact coordinates of [40.2944289205749, 75.27880969208869, 24.614055921407754]
# Current node is in region coordinates of [20, 37, 0]
# Current node has exact coordinates of [65.3871817472355, 95.3216133534936, 49.228111842815466]
# Current node is in region coordinates of [32, 47, 1]
# Current node has exact coordinates of [24.228193435259353, 62.477604271554, 24.614055921407754]
# Current node is in region coordinates of [12, 31, 0]
# Current node has exact coordinates of [37.39248790698647, 69.07023946316275, 49.228111842815466]
# Current node is in region coordinates of [18, 34, 1]
# Current node has exact coordinates of [40.269205853228634, 71.55307934075626, 49.228111842815466]
# Current node is in region coordinates of [20, 35, 1]
# Current node has exact coordinates of [10.815093672028654, 34.067383573974375, -61.53513980351933]
# Current node is in region coordinates of [5, 17, 9]
# Current node has exact coordinates of [10.973815574556973, 19.757419517946534, -98.45622368563106]
# Current node is in region coordinates of [5, 9, 8]
# Current node has exact coordinates of [54.6527955844394, 83.96727872872376, 49.228111842815466]
# Current node is in region coordinates of [27, 41, 1]
# Current node has exact coordinates of [44.347786279067506, 73.76720431452542, 49.228111842815466]
# Current node is in region coordinates of [22, 36, 1]
# Current node has exact coordinates of [47.22450422530967, 76.25004419211892, 49.228111842815466]
# Current node is in region coordinates of [23, 38, 1]
# Current node has exact coordinates of [50.10122217155184, 78.73288406971243, 49.228111842815466]
# Current node is in region coordinates of [25, 39, 1]
# Current node has exact coordinates of [52.977940117794006, 81.21572394730593, 49.228111842815466]
# Current node is in region coordinates of [26, 40, 1]
# Current node has exact coordinates of [58.73137601027834, 86.18140370249294, 49.228111842815466]
# Current node is in region coordinates of [29, 43, 1]
# Current node has exact coordinates of [61.608093956520506, 88.66424358008645, 49.228111842815466]
# Current node is in region coordinates of [30, 44, 1]
# Current node has exact coordinates of [64.4848119027627, 91.14708345767995, 49.228111842815466]
# Current node is in region coordinates of [32, 45, 1]
# Current node has exact coordinates of [67.36152984900501, 93.62992333527346, 49.228111842815466]
# Current node is in region coordinates of [33, 46, 1]
# Current node has exact coordinates of [70.23824779524732, 96.11276321286697, 49.228111842815466]
# Current node is in region coordinates of [35, 48, 1]
# Current node has exact coordinates of [32.61220190939094, 71.6595129127315, 86.14919572492714]
# Current node is in region coordinates of [16, 35, 2]
# Current node has exact coordinates of [17.754065702897176, 7.5372452648844614, 184.60541941055814]
# Current node is in region coordinates of [8, 3, 6]
# Current node has exact coordinates of [73.11496574148963, 98.59560309046047, 49.228111842815466]
# Current node is in region coordinates of [36, 49, 1]
# Current node has exact coordinates of [28.55740947829825, 10.996297026991478, 123.07027960703874]
# Current node is in region coordinates of [14, 5, 4]
# Current node has exact coordinates of [29.562372110359846, 65.46332241512964, 110.76325164633485]
# Current node is in region coordinates of [14, 32, 3]
# Current node has exact coordinates of [57.6593977529817, 92.0476236165267, 49.228111842815466]
# Current node is in region coordinates of [28, 46, 1]
# Current node has exact coordinates of [32.43909005660201, 67.94616229272314, 110.76325164633485]
# Current node is in region coordinates of [16, 33, 3]
# Current node has exact coordinates of [53.96565837998997, 87.62998644772306, 12.307027960703788]
# Current node is in region coordinates of [26, 43, 0]
# Current node has exact coordinates of [63.70323492051538, 93.55998231398692, 73.84216776422316]
# Current node is in region coordinates of [31, 46, 2]
# Current node has exact coordinates of [63.2829494231659, 91.41579836150427, 49.228111842815466]
# Current node is in region coordinates of [31, 45, 1]
# Current node has exact coordinates of [46.047864813059235, 80.2444894472757, 24.614055921407754]
# Current node is in region coordinates of [23, 40, 0]
# Current node has exact coordinates of [35.315808002844165, 70.42900217031665, 110.76325164633485]
# Current node is in region coordinates of [17, 35, 3]
# Current node has exact coordinates of [15.915685812358412, 54.504259100266346, 24.614055921407758]
# Current node is in region coordinates of [7, 27, 0]
# Current node has exact coordinates of [41.55641675054854, 73.52409704153541, 12.307027960703788]
# Current node is in region coordinates of [20, 36, 0]
# Current node has exact coordinates of [44.43313469679071, 76.00693691912892, 12.307027960703788]
# Current node is in region coordinates of [22, 38, 0]
# Current node has exact coordinates of [35.48891985563312, 74.142352790325, 86.14919572492714]
# Current node is in region coordinates of [17, 37, 2]
# Current node has exact coordinates of [38.19252594908633, 72.91184204791016, 110.76325164633485]
# Current node is in region coordinates of [19, 36, 3]
# Current node has exact coordinates of [47.309852643032876, 78.48977679672242, 12.307027960703788]
# Current node is in region coordinates of [23, 39, 0]
# Current node has exact coordinates of [11.47189027274575, 46.66874894855947, -36.921083882111624]
# Current node is in region coordinates of [5, 23, 10]
# Current node has exact coordinates of [34.601118378467504, 68.82713219017275, 12.307027960703788]
# Current node is in region coordinates of [17, 34, 0]
# Current node has exact coordinates of [50.18657058927504, 80.97261667431593, 12.307027960703788]
# Current node is in region coordinates of [25, 40, 0]
# Current node has exact coordinates of [4.9310063445549694, 34.56520631423445, -12.307027960703877]
# Current node is in region coordinates of [2, 17, 0]
# Current node has exact coordinates of [22.112879577773036, 60.128672188854864, 86.14919572492714]
# Current node is in region coordinates of [11, 30, 2]
# Current node has exact coordinates of [41.0692438953285, 75.39468192550366, 110.76325164633485]
# Current node is in region coordinates of [20, 37, 3]
# Current node has exact coordinates of [37.477836324709614, 71.30997206776622, 12.307027960703788]
# Current node is in region coordinates of [18, 35, 0]
# Current node has exact coordinates of [53.06328853551721, 83.45545655190944, 12.307027960703788]
# Current node is in region coordinates of [26, 41, 0]
# Current node has exact coordinates of [70.65853329259656, 98.25694716534962, 73.84216776422316]
# Current node is in region coordinates of [35, 49, 2]
# Current node has exact coordinates of [4.954145430813952, 28.017412882258707, 61.53513980351938]
# Current node is in region coordinates of [2, 14, 2]
# Current node has exact coordinates of [25.551924717122713, 63.13122869719358, 98.45622368563104]
# Current node is in region coordinates of [12, 31, 3]
# Current node has exact coordinates of [24.68353884993512, 64.3180003937828, 86.14919572492714]
# Current node is in region coordinates of [12, 32, 2]
# Current node has exact coordinates of [17.098140159077815, 56.660597895351316, 49.228111842815466]
# Current node is in region coordinates of [8, 28, 1]
# Current node has exact coordinates of [55.940006481759376, 85.93829642950294, 12.307027960703788]
# Current node is in region coordinates of [27, 42, 0]
# Current node has exact coordinates of [43.945961841570664, 77.87752180309717, 110.76325164633485]
# Current node is in region coordinates of [21, 38, 3]
# Current node has exact coordinates of [19.97485810531998, 59.14343777294482, 49.228111842815466]
# Current node is in region coordinates of [9, 29, 1]
# Current node has exact coordinates of [69.03638531565025, 96.38147811669128, 49.228111842815466]
# Current node is in region coordinates of [34, 48, 1]
# Current node has exact coordinates of [38.365637801875295, 76.62519266791851, 86.14919572492714]
# Current node is in region coordinates of [19, 38, 2]
# Current node has exact coordinates of [58.81672442800154, 88.42113630709645, 12.307027960703788]
# Current node is in region coordinates of [29, 44, 0]
# Current node has exact coordinates of [46.82267978781283, 80.36036168069067, 110.76325164633485]
# Current node is in region coordinates of [23, 40, 3]
# Current node has exact coordinates of [62.93074929834274, 94.98295742838272, 73.84216776422316]
# Current node is in region coordinates of [31, 47, 2]
# Current node has exact coordinates of [56.842376326232134, 90.11282632531656, 12.307027960703788]
# Current node is in region coordinates of [28, 45, 0]
# Current node has exact coordinates of [61.69344237424371, 90.90397618468995, 12.307027960703788]
# Current node is in region coordinates of [30, 45, 0]
# Current node has exact coordinates of [14.776061545613148, 13.932062373840635, 184.60541941055814]
# Current node is in region coordinates of [7, 6, 6]
# Current node has exact coordinates of [46.95023465753199, 84.41901934308932, 24.614055921407754]
# Current node is in region coordinates of [23, 42, 0]
# Current node has exact coordinates of [49.699397734055, 82.84320155828418, 110.76325164633485]
# Current node is in region coordinates of [24, 41, 3]
# Current node has exact coordinates of [51.86142605592044, 83.72417145573375, 12.307027960703788]
# Current node is in region coordinates of [25, 41, 0]
# Current node has exact coordinates of [41.24235574811746, 79.10803254551202, 86.14919572492714]
# Current node is in region coordinates of [20, 39, 2]
# Current node has exact coordinates of [66.57995286675755, 96.04282219158043, 73.84216776422316]
# Current node is in region coordinates of [33, 48, 2]
# Current node has exact coordinates of [21.167081071268328, 21.501478045954677, -36.92108388211169]
# Current node is in region coordinates of [10, 10, 10]
# Current node has exact coordinates of [13.236119866233139, 51.60609738798113, -36.921083882111624]
# Current node is in region coordinates of [6, 25, 10]
# Current node has exact coordinates of [64.57016032048587, 93.38681606228346, 12.307027960703788]
# Current node is in region coordinates of [32, 46, 0]
# Current node has exact coordinates of [5.573268706686605, 29.435201492678992, 98.45622368563099]
# Current node is in region coordinates of [2, 14, 3]
# Current node has exact coordinates of [35.708541080266414, 67.3086084236561, 73.84216776422316]
# Current node is in region coordinates of [17, 33, 2]
# Current node has exact coordinates of [19.85514257281723, 61.81744030344975, 24.614055921407758]
# Current node is in region coordinates of [9, 30, 0]
# Current node has exact coordinates of [38.585259026508524, 69.79144830124957, 73.84216776422316]
# Current node is in region coordinates of [19, 34, 2]
# Current node has exact coordinates of [41.98186766615062, 77.92682045318323, 73.84216776422316]
# Current node is in region coordinates of [20, 38, 2]
# Current node has exact coordinates of [54.678018651785735, 87.69300908005621, 24.614055921407754]
# Current node is in region coordinates of [27, 43, 0]
# Current node has exact coordinates of [52.576115680297164, 85.32604143587768, 110.76325164633485]
# Current node is in region coordinates of [26, 42, 3]
# Current node has exact coordinates of [61.59900259644585, 89.65416732199762, 73.84216776422316]
# Current node is in region coordinates of [30, 44, 2]
# Current node has exact coordinates of [42.66383945234751, 72.00557327501876, 73.84216776422316]
# Current node is in region coordinates of [21, 36, 2]
# Current node has exact coordinates of [48.417275344831786, 76.97125303020577, 73.84216776422316]
# Current node is in region coordinates of [24, 38, 2]
# Current node has exact coordinates of [51.29399329107395, 79.45409290779928, 73.84216776422316]
# Current node is in region coordinates of [25, 39, 2]
# Current node has exact coordinates of [54.17071123731612, 81.93693278539278, 73.84216776422316]
# Current node is in region coordinates of [27, 40, 2]
# Current node has exact coordinates of [59.92414712980045, 86.9026125405798, 73.84216776422316]
# Current node is in region coordinates of [29, 43, 2]
# Current node has exact coordinates of [62.80086507604262, 89.3854524181733, 73.84216776422316]
# Current node is in region coordinates of [31, 44, 2]
# Current node has exact coordinates of [65.6775830222848, 91.8682922957668, 73.84216776422316]
# Current node is in region coordinates of [32, 45, 2]
# Current node has exact coordinates of [68.55430096852696, 94.35113217336031, 73.84216776422316]
# Current node is in region coordinates of [34, 47, 2]
# Current node has exact coordinates of [71.43101891476914, 96.83397205095382, 73.84216776422316]
# Current node is in region coordinates of [35, 48, 2]
# Current node has exact coordinates of [74.30773686101136, 99.31681192854732, 73.84216776422316]
# Current node is in region coordinates of [37, 49, 2]
# Found Solution
# Animating Search Pattern

# %%
def draw_arc(x, y, theta, command, color_map, out):
    t = 0 
    dt = 0.01
    theta = 3.14 * theta / 180

    UL = command[0]
    UR = command[1]

    # generate the subpoints for the curve and
    # append the points to the x and y list
    while t<1:
        t = t + dt

        old_x = x
        old_y = y

        x += 0.5*r * (UL + UR) * math.cos(theta) * dt
        y += 0.5*r * (UL + UR) * math.sin(theta) * dt
        theta += (r / L) * (UR - UL) * dt

        cv2.line(color_map,np.array([x, y], dtype=np.int32),np.array([old_x, old_y], dtype=np.int32),[255, 255, 255],1)
        out.write(np.flipud(color_map))

# %%
# gazebo_world = np.zeros(shape=[100, 100, 3], dtype=np.uint8)
test = deepcopy(color_map)
out = cv2.VideoWriter('real_path.avi',cv2.VideoWriter_fourcc(*'DIVX'), 60, (200, 200))

for n in range(1, len(solution_path)):
    x = solution_path[n].cell_location[1]
    y = solution_path[n].cell_location[0]
    theta = solution_path[n-1].cell_location[2]
    command = node.command

    draw_arc(x, y, theta, command, test, out)

out.release()

# %%
plt.figure(figsize=(10, 10))
plt.imshow(test, origin='bottom')

# %%
test = deepcopy(color_map)
for node in solution_path[1:]:
    xs = node.local_path[0]
    ys = node.local_path[1]
    if len(xs) > 0:
        for i in range(0, len(xs)): # get the number of points in the local path
            cv2.line(test,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[255, 255, 255],1)        

plt.figure(figsize = [10, 10])
plt.imshow(test, origin = "bottom")
