# %%
#!/usr/bin/env python3
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from copy import deepcopy
import cv2
from cv2 import VideoWriter, VideoWriter_fourcc
import sys
import math

# %%
# node class that each spot in the map will occupy
# cell location and goal_location are tuples representing index 
# of current cell location and goal cell locations
# local path represents the path to get to this 
# node from the optimal parent node
class Node:
    def __init__(self, parent, cell_location, region, c2c, c2g, local_path, command):
        self.parent = parent
        self.cell_location = cell_location
        self.region = region
        self.c2c = c2c
        self.c2g = c2g
        self.h = c2c+c2g
        self.local_path = local_path
        self.command = command

# %%
# given 2 points of a line, retrun a lambda function which caluclates the 
# y value of an x
def generate_line_eq(p1, p2):
    
    x1 = p1[0]
    y1 = p1[1]
    
    x2 = p2[0]
    y2 = p2[1]
    
    m = (y2-y1)/(x2-x1)
    b = y1-m*x1
    
    lin_func = lambda x: m*x+b
    
    return lin_func

# %%
# hardcoded obstacles defined by their vertices and origins
# we just see if the current x and y are within bounding lines
def check_obstacle(x, y):
    
    # check bottom circle
    if y <= 60 and y >= 20 and x <= np.sqrt(20**2 - (y-40)**2) + 40 and x >= -np.sqrt(20**2 - (y-40)**2) + 40:
        return True

    #check top circle
    if y <= 180 and y >= 140 and x <= np.sqrt(20**2 - (y-160)**2) + 40 and x >= -np.sqrt(20**2 - (y-160)**2) + 40:
        return True

    # check left square
    if x >= 5 and x <= 35 and y >= 85 and y <= 115:
        return True

    # check middle rectangle
    if x >= 75 and x <= 125 and y >= 85 and y <= 115:
        return True

    # check right rectangle
    if x >= 145 and x <= 175 and y >= 40 and y <= 80:
        return True
    

    return False

# %%
# iterate over the board, and if the cell is an obstacle, generate 
# the a circle of points around it which are padding
def generate_margin(color_map, radius):

    height = len(color_map)
    width = len(color_map[0])

    for y in range(len(color_map)):
        for x in range(len(color_map[y])):

            # read the color map and check to see if the current space is an obstacle
            if (color_map[y][x][0] == 255 and color_map[y][x][1] == 0 and 
                color_map[y][x][2] == 0):

                # generate circle bounds for a point if it is an obstacle
                x_range = range(x-radius, x+radius+1)

                for x_i in x_range:
                    y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
                    y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

                    y_range = np.arange(y_lower_limit, y_upper_limit+1)
                    for y_i in y_range:
                        if (x_i >= 0 and x_i <= width) and (y_i >= 0 and y_i <= height):
                            if not (color_map[int(y_i)][x_i][0] == [255] and 
                                    color_map[int(y_i)][x_i][1] == [0] and 
                                    color_map[int(y_i)][x_i][2] == [0]):
                                color_map[int(y_i)][x_i] = [0,255,0]
    return color_map

# %%
# draw a circle (red in numpy, blue in opencv) to represent the acceptable goal zone
def expand_goal(color_map, goal_location, radius):

    x = goal_location[1]
    y = goal_location[0]

    height = len(color_map)
    width = len(color_map[0])

    x_range = range(x-radius, x+radius+1)
    for x_i in x_range:
        y_upper_limit = np.ceil(np.sqrt(radius**2-(x_i-x)**2) + y)
        y_lower_limit = np.floor(-np.sqrt(radius**2-(x_i-x)**2) + y)

        y_range = np.arange(y_lower_limit, y_upper_limit+1)
        for y_i in y_range:
            if (x_i >= 0 and x_i <= width) and (y_i >= 0 and y_i <= height):
                if not (int(color_map[int(y_i)][int(x_i)][0]) == 255 or\
                       int(color_map[int(y_i)][int(x_i)][1]) == 255):
                    color_map[int(y_i)][int(x_i)] = [0,0,255]

    return color_map

# %%
# read the board and depending on each nodes status
# write the proper color in a numpy array as BGR colors
def create_color_map(height, width, radius, goal_location):

    color_map = np.zeros(shape=[height, width, 3], dtype=np.uint8)

    for row in range(height):
        for col in range(width):
            if check_obstacle(col, row):
                color_map[row][col][0] = 255
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

            else:
                color_map[row][col][0] = 0
                color_map[row][col][1] = 0
                color_map[row][col][2] = 0

    color_map = expand_goal(color_map, goal_location, 5)
    color_map = generate_margin(color_map, 2)


    return color_map

# %%
# pass in color map coordinates and convert them to board 
# coordinates which have been compressed/expanded coordinates 
# by the neighborhood threshold
def compress_coordinates(x, y, theta, thresh):
    compressed_x = int(np.floor(x/thresh))
    compressed_y = int(np.floor(y/thresh))
    compressed_angle = 0 if theta == 0 else (int(np.floor(360/theta))-1)%12

    return compressed_x, compressed_y, compressed_angle

# %%
# will be used when iterating over closed nodes
# updates the previous color map given the current node to a specifies color
def update_color_map(curr_node, color_map, brg_color):

    row = int(np.floor(curr_node.cell_location[0]))
    col = int(np.floor(curr_node.cell_location[1]))

    color_map[row][col][0] = brg_color[0]
    color_map[row][col][1] = brg_color[1]
    color_map[row][col][2] = brg_color[2]

    return color_map

# %%
# create the board
# returns a 3d array
# dimensions are height width and angle. Takes in a compressed version of 
# the height width and angle which handles the region/node similarity
def create_board(width, height, thresh):

    compressed_width, compressed_height, compressed_angle = compress_coordinates(x=width, y=height, theta=30, thresh=thresh)

    board = []
    for row_num in range(0, compressed_height):
        temp_row = []
        for col_num in range(0, compressed_width):

            temp_configuration = []
            for angle in range(0,compressed_angle+1):

                c2c = np.Infinity
                c2g = np.Infinity

                # c2g = np.sqrt((row_num-goal_location[0])**2 + (col_num-goal_location[1]**2))

                new_node = Node(parent=None, 
                                c2c=c2c,
                                c2g=c2g,
                                cell_location=[int(row_num*thresh), int(col_num*thresh), angle],
                                region=[row_num, col_num, angle],
                                local_path=[],
                                command = None)

                temp_configuration.append(new_node)
            temp_row.append(temp_configuration)
        board.append(temp_row)

    return board

# %%
# generates a series of x and y values representing a curve given wheel velocities
# also returns the final theta orientation of the node, as well as the total cost of the path
# path validity is not checked here
def generate_curve(x,y,theta,UL,UR):

    # robot parameters
    t = 0
    r = 5
    L = 50
    dt = 0.05
    cost=0


    # list of x and y values
    # will be set to the nodes local_path so we can graph it
    x_res = [x]
    y_res = [y]

    theta = 3.14 * theta / 180

    # generate the subpoints for the curve and
    # append the points to the x and y list
    while t<1:
        t = t + dt
        x += 0.5*r * (UL + UR) * math.cos(theta) * dt
        y += 0.5*r * (UL + UR) * math.sin(theta) * dt
        theta += (r / L) * (UR - UL) * dt
        cost = cost+ math.sqrt(math.pow((0.5*r * (UL + UR) * math.cos(theta) * dt),2)+math.pow((0.5*r * (UL + UR) * math.sin(theta) * dt),2))
        
        x_res.append(x)
        y_res.append(y)
        
    theta = 180 * (theta) / 3.14
    
    # retrun the x and ys to be plotted as well as the end theta, and cost of the curve 
    return x_res, y_res, theta, cost

# %%
# uses the predefined differential commands to generate the arc of the robots path
# for each point in the arc, check bounds and if in opstacle or margin, and disqualify arcs which contain invalid points
# if arc is valid then pull the node it ends on compare costs, and if cheaper, then update the cost and local path to the node

def gen_next_nodes(curr_node, color_map, board, goal_location, thresh):

    curr_y = curr_node.cell_location[0]
    curr_x = curr_node.cell_location[1]
    curr_angle = curr_node.cell_location[2]

    next_nodes = []

    actions=[[7, 3], [10, 0], [5, 5], [0,10], [3, 7]]
    for action in actions:

        x_res, y_res, theta, cost = generate_curve(curr_x, curr_y, curr_angle, action[0], action[1])

        valid = True

        # bounds checking
        for x in x_res:
            if int(x) < 0 or int(x) > 399:
                valid = False
        for y in y_res:
            if int(y) < 0 or int(y) > 249:
                valid = False


        if valid:
            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

            for i in range(len(x_res)):
                if int(color_map[int(y_res[i])][int(x_res[i])][0]) == 0 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][1]) == 255 and\
                   int(color_map[int(y_res[i])][int(x_res[i])][2]) == 0:
                    valid = False

        
        if valid:

            # use compressed coordinates to access a new node
            comp_x, comp_y, comp_angle = compress_coordinates(
                math.floor(x_res[-1]),
                math.floor(y_res[-1]),
                theta,
                thresh=thresh
            )

            c2c = curr_node.c2c + cost
            c2g = np.sqrt((x_res[-1]-goal_location[1])**2 + (y_res[-1]-goal_location[0])**2)
            h = c2g+c2c


            new_node = board[comp_y][comp_x][comp_angle]
            if h < new_node.h:
                new_node.parent = curr_node
                new_node.cell_location = [y_res[-1], x_res[-1], theta]
                new_node.c2c = c2c
                new_node.c2g = c2g
                new_node.h = h
                new_node.local_path = [x_res, y_res]
                new_node.command = action

            next_nodes.append(new_node)
                

    return next_nodes

# %%
# this is the backtracking function
# returns a list of nodes in order to find the solution
def get_solution_path(curr_node):
    solution_path= []
    
    while curr_node:
        solution_path.insert(0, curr_node)
        curr_node = curr_node.parent
        
    return solution_path

# %%
# get the command to get to each spot in the solution path
# the first element will always be 0 since we dont have to move to get there
def get_commands(solution_path):
    commands = list(node.command for node in solution_path)
    commands = list(filter(None, commands))
    return commands

# %%
# plot the chronologically ordered list of nodes in closed nodes, and then generate and plot the path for the solution

def animate(color_map, closed_nodes, solution_path):

    # draw explored nodes
    out = cv2.VideoWriter('test.avi',cv2.VideoWriter_fourcc(*'DIVX'), 60, (400, 250))
    for node in closed_nodes[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[255, 255, 255],1)        
                out.write(np.flipud(color_map))


    # draw the backtracked best path
    for node in solution_path[1:]:
        xs = node.local_path[0]
        ys = node.local_path[1]
        if len(xs) > 0:
            for i in range(1, len(xs)): # get the number of points in the local path
                cv2.line(color_map,np.array([xs[i], ys[i]], dtype=np.int32),np.array([xs[i-1], ys[i-1]], dtype=np.int32),[0, 0, 255],1)        
                out.write(np.flipud(color_map))

    out.release()

# %%
# make sure that the user defined paramters are fine
# not out of bounds and is a free space for start and goal

def validate_inputs(height, width, start_location, goal_location, color_map):
    if start_location[0] not in range(0, height) or start_location[1] not in range(0, width):
        print("Start Location Out Of Bounds")
        return False

    if goal_location[0] not in range(0, height) or goal_location[1] not in range(0, width):
        print("Goal Location Out Of Bounds")
        return False

    if color_map[start_location[0]][start_location[1]][0] == 255 or color_map[start_location[0]][start_location[1]][1] == 255:
        print('Cannot start in obstacle or obstacle margin')
        return False

    if color_map[goal_location[0]][goal_location[1]][0] == 255 or color_map[goal_location[0]][goal_location[1]][1] == 255:
        print('Cannot place goal in obstacle or obstacle margin')
        return False

    return True

# %%
# starting paramters
start_location = [0,0,0]
goal_location = [150,150,0]

width = 200
height = 200

step = 3
thresh = 1

print('Building Color Map')
color_map = create_color_map(height = height, width = width, radius=15, goal_location=goal_location)

print('Building Board')
board = create_board(width=width, height=height, thresh=thresh)

plt.figure(figsize=(10, 10))
plt.imshow(color_map, origin='lower')
# Out:
# Building Color Map
# Building Board

# %%
compressed_x_start, compressed_y_start, compressed_angle_start = compress_coordinates(
        start_location[1],
        start_location[0],
        start_location[2],
        thresh=thresh
    )

compressed_x_goal, compressed_y_goal, compressed_angle_goal = compress_coordinates(
    goal_location[1],
    goal_location[0],
    goal_location[2],
    thresh=thresh
)

print(f'Starting in region x: {compressed_x_start}, y: {compressed_y_start}, theta: {compressed_angle_start}')
print(f'Goal in region x: {compressed_x_goal}, y: {compressed_y_goal}, theta: {compressed_angle_goal}')
# Out:
# Starting in region x: 0, y: 0, theta: 0
# Goal in region x: 150, y: 150, theta: 0

# %%
start_node = board[compressed_y_start][compressed_x_start][compressed_angle_start]
goal_node = board[compressed_y_goal][compressed_x_goal][compressed_angle_goal]

start_node.c2c = 0
goal_region = goal_node.region

open_nodes = [start_node]
closed_nodes = []

found = False
solution_path = None
commands = None

print(f'Searching for goal region: {goal_region}')
while len(open_nodes) > 0:

    open_nodes.sort(key=lambda x: x.h)
    curr_node = open_nodes.pop(0)
    closed_nodes.append(curr_node)

    curr_x = curr_node.cell_location[1]
    curr_y = curr_node.cell_location[0]


    print(f"Current node has exact coordinates of x:{curr_x} y:{curr_y} Theta:{curr_node.cell_location[2]}")
    print(f"Current node is in region coordinates of {curr_node.region}")
    # print(f"Current node has coordinates of {curr_node.cell_location}")


    if int(color_map[int(curr_y)][int(curr_x)][0]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][1]) == 0 and\
       int(color_map[int(curr_y)][int(curr_x)][2]) == 255:
        print('Found Solution')
        found = True

        print('Animating Search Pattern')          
        # back track and animate the search and solution
        solution_path = get_solution_path(curr_node)
        commands = get_commands(solution_path)
        animate(color_map, closed_nodes, solution_path)

        break

    else:
        next_possible_nodes = gen_next_nodes(
            curr_node=curr_node,
            board=board,
            goal_location=goal_location,
            color_map=color_map,
            thresh=thresh
        )
        
        for node in next_possible_nodes:

            appendable = True
            for o_node in open_nodes:
                if o_node.region == node.region:
                    appendable = False
                    break
            if appendable:
                for c_node in closed_nodes:
                    if c_node.region == node.region:
                        appendable = False
                        break

            if appendable:
                open_nodes.append(node)

if not found:
    print('No Solution')
# Out:
# Searching for goal region: [150, 150, 0]
# Current node has exact coordinates of x:0 y:0 Theta:0
# Current node is in region coordinates of [0, 0, 0]
# Current node has exact coordinates of x:21.319702835028856 y:10.964128629201246 Theta:57.32484076433121
# Current node is in region coordinates of [10, 21, 5]
# Current node has exact coordinates of x:24.38717197941707 y:4.690136953517899 Theta:22.929936305732497
# Current node is in region coordinates of [4, 24, 2]
# Current node has exact coordinates of x:45.022819486058765 y:18.50685124375533 Theta:45.859872611465
# Current node is in region coordinates of [18, 45, 6]
# Current node has exact coordinates of x:47.41369682948922 y:14.425595511234162 Theta:22.929936305732497
# Current node is in region coordinates of [14, 47, 2]
# Current node has exact coordinates of x:25.0 y:0.0 Theta:0.0
# Current node is in region coordinates of [0, 25, 0]
# Current node has exact coordinates of x:62.78081071892466 y:32.82651006135173 Theta:80.25477707006374
# Current node is in region coordinates of [32, 62, 3]
# Current node has exact coordinates of x:68.04934433613093 y:28.242309801471592 Theta:45.859872611465
# Current node is in region coordinates of [28, 68, 6]
# Current node has exact coordinates of x:81.67555236543498 y:49.0042460439936 Theta:68.78980891719749
# Current node is in region coordinates of [49, 81, 4]
# Current node has exact coordinates of x:77.20905729448178 y:51.97246384606906 Theta:22.929936305732483
# Current node is in region coordinates of [51, 77, 2]
# Current node has exact coordinates of x:94.88382420115092 y:70.03453603035024 Theta:45.85987261146499
# Current node is in region coordinates of [70, 94, 6]
# Current node has exact coordinates of x:85.46701206981007 y:46.17621207395966 Theta:45.859872611465
# Current node is in region coordinates of [46, 85, 6]
# Current node has exact coordinates of x:71.54772285813605 y:56.061672925850154 Theta:57.324840764331235
# Current node is in region coordinates of [56, 71, 5]
# Current node has exact coordinates of x:99.09322009911412 y:66.93814831648167 Theta:68.78980891719749
# Current node is in region coordinates of [66, 99, 4]
# Current node has exact coordinates of x:88.6707822733786 y:74.04867873722668 Theta:34.39490445859873
# Current node is in region coordinates of [74, 88, 9]
# Current node has exact coordinates of x:85.05528050483944 y:77.09844754604752 Theta:57.324840764331235
# Current node is in region coordinates of [77, 85, 5]
# Current node has exact coordinates of x:90.73449622735174 y:72.30522319317423 Theta:68.78980891719749
# Current node is in region coordinates of [72, 90, 4]
# Current node has exact coordinates of x:48.675670201337745 y:9.867046834921611 Theta:-7.955419762441408e-16
# Current node is in region coordinates of [9, 48, 3]
# Current node has exact coordinates of x:102.8846798034892 y:64.11011434644773 Theta:45.859872611465
# Current node is in region coordinates of [64, 102, 6]
# Current node has exact coordinates of x:92.5761711839172 y:70.37337839618664 Theta:80.25477707006374
# Current node is in region coordinates of [70, 92, 3]
# Current node has exact coordinates of x:46.31970283502888 y:10.964128629201246 Theta:57.32484076433121
# Current node is in region coordinates of [10, 46, 5]
# Current node has exact coordinates of x:63.44276225027142 y:28.95113444057778 Theta:34.39490445859872
# Current node is in region coordinates of [28, 63, 9]
# Current node has exact coordinates of x:70.44022167956133 y:24.16105406895042 Theta:22.929936305732497
# Current node is in region coordinates of [24, 70, 2]
# Current node has exact coordinates of x:99.61990843683381 y:64.902105357576 Theta:11.464968152866257
# Current node is in region coordinates of [64, 99, 6]
# Current node has exact coordinates of x:88.40454898695299 y:42.46894627744761 Theta:22.929936305732497
# Current node is in region coordinates of [42, 88, 2]
# Current node has exact coordinates of x:75.03773988901993 y:51.17491046445722 Theta:103.18471337579625
# Current node is in region coordinates of [51, 75, 2]
# Current node has exact coordinates of x:97.84470480112348 y:65.78917813630649 Theta:45.859872611464986
# Current node is in region coordinates of [65, 97, 6]
# Current node has exact coordinates of x:80.77755395105733 y:79.11686235887288 Theta:80.25477707006374
# Current node is in region coordinates of [79, 80, 3]
# Current node has exact coordinates of x:120.30234753716834 y:82.0440166189358 Theta:45.859872611465
# Current node is in region coordinates of [82, 120, 6]
# Current node has exact coordinates of x:92.45540762269907 y:69.1088127369453 Theta:103.18471337579625
# Current node is in region coordinates of [69, 92, 2]
# Current node has exact coordinates of x:67.02998929143061 y:57.46275331106323 Theta:80.25477707006374
# Current node is in region coordinates of [57, 67, 3]
# Current node has exact coordinates of x:80.9221133018159 y:46.592104612688225 Theta:57.32484076433121
# Current node is in region coordinates of [46, 80, 5]
# Current node has exact coordinates of x:94.42967094851929 y:67.62887923288567 Theta:57.32484076433121
# Current node is in region coordinates of [67, 94, 5]
# Current node has exact coordinates of x:86.14104228271505 y:73.43355101967985 Theta:91.71974522293
# Current node is in region coordinates of [73, 86, 2]
# Current node has exact coordinates of x:117.03757617051295 y:82.83600763006406 Theta:11.464968152866257
# Current node is in region coordinates of [82, 117, 6]
# Current node has exact coordinates of x:105.82221672063213 y:60.40284854993569 Theta:22.929936305732497
# Current node is in region coordinates of [60, 105, 2]
# Current node has exact coordinates of x:98.04517271705845 y:64.57911042406474 Theta:34.39490445859872
# Current node is in region coordinates of [64, 98, 9]
# Current node has exact coordinates of x:74.84785959149804 y:50.038230025526246 Theta:91.71974522292997
# Current node is in region coordinates of [50, 74, 2]
# Current node has exact coordinates of x:85.80733556899675 y:42.56196861906799 Theta:80.25477707006374
# Current node is in region coordinates of [42, 85, 3]
# Current node has exact coordinates of x:90.15194439473717 y:69.64729404571095 Theta:80.25477707006372
# Current node is in region coordinates of [69, 90, 3]
# Current node has exact coordinates of x:92.29280357550007 y:68.07764028606125 Theta:3.977709881220704e-15
# Current node is in region coordinates of [68, 92, 7]
# Current node has exact coordinates of x:103.7716628763884 y:60.869860827565184 Theta:80.25477707006374
# Current node is in region coordinates of [60, 103, 3]
# Current node has exact coordinates of x:81.45823586698772 y:76.60870709578055 Theta:22.929936305732483
# Current node is in region coordinates of [76, 81, 2]
# Current node has exact coordinates of x:84.07615262301346 y:43.06719627545368 Theta:34.39490445859872
# Current node is in region coordinates of [43, 84, 9]
# Current node has exact coordinates of x:94.57424770820815 y:65.79713148356642 Theta:57.324840764331235
# Current node is in region coordinates of [65, 94, 5]
# Current node has exact coordinates of x:115.52452376860293 y:82.2200805961752 Theta:57.32484076433121
# Current node is in region coordinates of [82, 115, 5]
# Current node has exact coordinates of x:100.23558214455379 y:61.70792240378539 Theta:22.929936305732483
# Current node is in region coordinates of [61, 100, 2]
# Current node has exact coordinates of x:123.23988445431127 y:78.33675082242374 Theta:22.929936305732497
# Current node is in region coordinates of [78, 123, 2]
# Current node has exact coordinates of x:75.79690143064201 y:80.69791617556166 Theta:57.324840764331235
# Current node is in region coordinates of [80, 75, 5]
# Current node has exact coordinates of x:91.07586918620304 y:37.977768359187856 Theta:45.859872611465
# Current node is in region coordinates of [37, 91, 6]
# Current node has exact coordinates of x:101.55550367455794 y:60.708166447564125 Theta:57.32484076433121
# Current node is in region coordinates of [60, 101, 5]
# Current node has exact coordinates of x:85.18478801121094 y:71.6689895225328 Theta:34.39490445859871
# Current node is in region coordinates of [71, 85, 9]
# Current node has exact coordinates of x:115.06306132126133 y:81.74494106776147 Theta:57.32484076433121
# Current node is in region coordinates of [81, 115, 5]
# Current node has exact coordinates of x:95.48124996424008 y:64.15429186040215 Theta:91.71974522292997
# Current node is in region coordinates of [64, 95, 2]
# Current node has exact coordinates of x:67.06478355239292 y:22.98009598941237 Theta:-5.568793833708985e-15
# Current node is in region coordinates of [22, 67, 7]
# Current node has exact coordinates of x:49.38717197941707 y:4.690136953517899 Theta:22.929936305732497
# Current node is in region coordinates of [4, 49, 2]
# Current node has exact coordinates of x:121.18933061006754 y:78.80376310005326 Theta:80.25477707006374
# Current node is in region coordinates of [78, 121, 3]
# Current node has exact coordinates of x:118.19990945194554 y:80.0158146122825 Theta:22.92993630573248
# Current node is in region coordinates of [80, 118, 2]
# Current node has exact coordinates of x:104.70207721550709 y:58.73970460170987 Theta:68.78980891719749
# Current node is in region coordinates of [58, 104, 4]
# Current node has exact coordinates of x:118.33640053743835 y:79.8832524771932 Theta:68.78980891719749
# Current node is in region coordinates of [79, 118, 4]
# Current node has exact coordinates of x:69.99537303636662 y:20.831175464122854 Theta:57.32484076433121
# Current node is in region coordinates of [20, 69, 5]
# Current node has exact coordinates of x:83.50293068307 y:41.86795008432028 Theta:57.32484076433121
# Current node is in region coordinates of [41, 83, 5]
# Current node has exact coordinates of x:97.0104883297734 y:62.90472470451774 Theta:57.32484076433121
# Current node is in region coordinates of [62, 97, 5]
# Current node has exact coordinates of x:113.76102107742385 y:82.04068175089044 Theta:68.78980891719749
# Current node is in region coordinates of [82, 113, 4]
# Current node has exact coordinates of x:71.70219505140989 y:19.602505392637873 Theta:-7.955419762441408e-16
# Current node is in region coordinates of [19, 71, 3]
# Current node has exact coordinates of x:117.91034905122302 y:79.76999458806651 Theta:45.85987261146499
# Current node is in region coordinates of [79, 117, 6]
# Current node has exact coordinates of x:90.05651414150266 y:67.19821186877951 Theta:80.25477707006374
# Current node is in region coordinates of [67, 90, 3]
# Current node has exact coordinates of x:109.04019649359469 y:56.28566056768505 Theta:45.859872611465
# Current node is in region coordinates of [56, 109, 6]
# Current node has exact coordinates of x:62.30393446922987 y:57.656011281450695 Theta:103.18471337579625
# Current node is in region coordinates of [57, 62, 2]
# Current node has exact coordinates of x:80.87124943685862 y:74.42812555241619 Theta:45.859872611464986
# Current node is in region coordinates of [74, 80, 6]
# Current node has exact coordinates of x:79.22520412928789 y:43.88636489714556 Theta:80.25477707006372
# Current node is in region coordinates of [43, 79, 3]
# Current node has exact coordinates of x:92.73276177599128 y:64.923139517343 Theta:80.25477707006372
# Current node is in region coordinates of [64, 92, 3]
# Current node has exact coordinates of x:87.11843245160917 y:38.818181275499384 Theta:34.39490445859872
# Current node is in region coordinates of [38, 87, 9]
# Current node has exact coordinates of x:100.62599009831256 y:59.8549558956968 Theta:34.39490445859872
# Current node is in region coordinates of [59, 100, 9]
# Current node has exact coordinates of x:108.49353691988217 y:55.911670631675925 Theta:45.859872611465
# Current node is in region coordinates of [55, 108, 6]
# Current node has exact coordinates of x:114.13354774501595 y:80.89173051589428 Theta:34.39490445859872
# Current node is in region coordinates of [80, 114, 9]
# Current node has exact coordinates of x:118.67856308980049 y:78.69517225894067 Theta:34.39490445859872
# Current node is in region coordinates of [78, 118, 9]
# Current node has exact coordinates of x:64.7542858688525 y:23.09105150363547 Theta:80.25477707006374
# Current node is in region coordinates of [23, 64, 3]
# Current node has exact coordinates of x:115.6026960339892 y:80.10883695390295 Theta:80.25477707006374
# Current node is in region coordinates of [80, 115, 3]
# Current node has exact coordinates of x:122.66640452289874 y:77.04759681020705 Theta:68.78980891719749
# Current node is in region coordinates of [77, 122, 4]
# Current node has exact coordinates of x:98.06426473909204 y:60.91036902217349 Theta:103.18471337579625
# Current node is in region coordinates of [60, 98, 2]
# Current node has exact coordinates of x:86.21861436180747 y:38.85023047960362 Theta:11.464968152866215
# Current node is in region coordinates of [38, 86, 6]
# Current node has exact coordinates of x:104.7095429957555 y:57.183258110329604 Theta:34.39490445859872
# Current node is in region coordinates of [57, 104, 9]
# Current node has exact coordinates of x:101.66719401917992 y:58.60807197289933 Theta:-5.568793833708985e-15
# Current node is in region coordinates of [58, 101, 7]
# Current node has exact coordinates of x:122.11974494918623 y:76.67360687419793 Theta:68.78980891719749
# Current node is in region coordinates of [76, 122, 4]
# Current node has exact coordinates of x:73.8408113451512 y:79.92552824644595 Theta:114.64968152866248
# Current node is in region coordinates of [79, 73, 2]
# Current node has exact coordinates of x:115.1747516658833 y:79.64484659309676 Theta:-5.568793833708985e-15
# Current node is in region coordinates of [79, 115, 7]
# Current node has exact coordinates of x:87.99211626849929 y:67.12152776164399 Theta:57.32484076433121
# Current node is in region coordinates of [67, 87, 5]
# Current node has exact coordinates of x:116.0285920464837 y:79.2182612306707 Theta:103.18471337579625
# Current node is in region coordinates of [79, 116, 2]
# Current node has exact coordinates of x:90.76810879614665 y:35.89734650823752 Theta:-11.464968152866218
# Current node is in region coordinates of [35, 90, 3]
# Current node has exact coordinates of x:93.653450704845 y:63.03231868186289 Theta:22.929936305732475
# Current node is in region coordinates of [63, 93, 2]
# Current node has exact coordinates of x:78.82390291280566 y:74.55195314755537 Theta:68.78980891719746
# Current node is in region coordinates of [74, 78, 4]
# Current node has exact coordinates of x:98.52352979283579 y:59.905276860447856 Theta:91.71974522292997
# Current node is in region coordinates of [59, 98, 2]
# Current node has exact coordinates of x:112.03108743953918 y:80.94205148064526 Theta:91.71974522292997
# Current node is in region coordinates of [80, 112, 2]
# Current node has exact coordinates of x:73.5211980080639 y:46.3262143681339 Theta:57.324840764331235
# Current node is in region coordinates of [46, 73, 5]
# Current node has exact coordinates of x:48.29355146013725 y:2.8937890764602914 Theta:-34.39490445859871
# Current node is in region coordinates of [2, 48, 0]
# Current node has exact coordinates of x:83.21520178883104 y:70.455959933284 Theta:114.64968152866247
# Current node is in region coordinates of [70, 83, 2]
# Current node has exact coordinates of x:70.02281948605876 y:18.50685124375533 Theta:45.859872611465
# Current node is in region coordinates of [18, 70, 6]
# Current node has exact coordinates of x:79.18253244440962 y:42.2370052883528 Theta:22.929936305732483
# Current node is in region coordinates of [42, 79, 2]
# Current node has exact coordinates of x:71.27916786393652 y:82.09899656077484 Theta:80.25477707006374
# Current node is in region coordinates of [82, 71, 3]
# Current node has exact coordinates of x:104.59778350315365 y:56.45915144760983 Theta:57.32484076433121
# Current node is in region coordinates of [56, 104, 5]
# Current node has exact coordinates of x:115.48193247277118 y:78.84427129466158 Theta:103.18471337579625
# Current node is in region coordinates of [78, 115, 2]
# Current node has exact coordinates of x:83.64902751536282 y:39.26878748627735 Theta:68.78980891719749
# Current node is in region coordinates of [39, 83, 4]
# Current node has exact coordinates of x:93.46674652963334 y:33.89651262666669 Theta:22.929936305732497
# Current node is in region coordinates of [33, 93, 2]
# Current node has exact coordinates of x:118.10534114985704 y:77.49592606780725 Theta:57.32484076433121
# Current node is in region coordinates of [77, 118, 5]
# Current node has exact coordinates of x:113.82761459607492 y:79.51434088063256 Theta:80.25477707006372
# Current node is in region coordinates of [79, 113, 3]
# Current node has exact coordinates of x:117.60258866116664 y:77.68957273711617 Theta:-11.464968152866225
# Current node is in region coordinates of [77, 117, 3]
# Current node has exact coordinates of x:90.64425742330646 y:64.31322017951041 Theta:34.39490445859873
# Current node is in region coordinates of [64, 90, 9]
# Current node has exact coordinates of x:96.85729935107875 y:60.29907747263399 Theta:45.85987261146499
# Current node is in region coordinates of [60, 96, 6]
# Current node has exact coordinates of x:116.11464033698212 y:78.27035369527809 Theta:91.71974522292997
# Current node is in region coordinates of [78, 116, 2]
# Current node has exact coordinates of x:126.45786422727383 y:74.21956284017311 Theta:45.859872611465
# Current node is in region coordinates of [74, 126, 6]
# Current node has exact coordinates of x:110.4835073803828 y:81.06101371515601 Theta:68.78980891719749
# Current node is in region coordinates of [81, 110, 4]
# Current node has exact coordinates of x:138.6069983437467 y:96.73766537254129 Theta:80.25477707006374
# Current node is in region coordinates of [96, 138, 3]
# Current node has exact coordinates of x:142.85617691625262 y:121.37390862225293 Theta:80.25477707006374
# Current node is in region coordinates of [121, 142, 3]
# Current node has exact coordinates of x:92.70797137727958 y:62.56976463545803 Theta:68.78980891719749
# Current node is in region coordinates of [62, 92, 4]
# Current node has exact coordinates of x:87.4404872197379 y:36.440753516243404 Theta:45.859872611465
# Current node is in region coordinates of [36, 87, 6]
# Current node has exact coordinates of x:79.18191558485815 y:72.84797941731756 Theta:126.11464968152869
# Current node is in region coordinates of [72, 79, 1]
# Current node has exact coordinates of x:113.61250641052892 y:79.04176891526248 Theta:57.324840764331235
# Current node is in region coordinates of [79, 113, 5]
# Current node has exact coordinates of x:101.49755551640241 y:57.14937372747277 Theta:-1.3524213596150394e-14
# Current node is in region coordinates of [57, 101, 7]
# Current node has exact coordinates of x:108.18577652982579 y:53.83124878072559 Theta:-11.464968152866218
# Current node is in region coordinates of [53, 108, 3]
# Current node has exact coordinates of x:125.91120465356131 y:73.845572904164 Theta:45.859872611465
# Current node is in region coordinates of [73, 125, 6]
# Current node has exact coordinates of x:108.86045821254869 y:81.53603635745439 Theta:34.39490445859871
# Current node is in region coordinates of [81, 108, 9]
# Current node has exact coordinates of x:109.02056459428042 y:81.43323323198044 Theta:80.25477707006372
# Current node is in region coordinates of [81, 109, 3]
# Current node has exact coordinates of x:108.12360847485094 y:81.95419035162087 Theta:57.324840764331235
# Current node is in region coordinates of [81, 108, 5]
# Current node has exact coordinates of x:101.06669524904196 y:57.202689758765416 Theta:68.78980891719749
# Current node is in region coordinates of [57, 101, 4]
# Current node has exact coordinates of x:85.33045931930195 y:67.39146983916696 Theta:103.18471337579625
# Current node is in region coordinates of [67, 85, 2]
# Current node has exact coordinates of x:147.10535548875853 y:146.01015187196435 Theta:80.25477707006374
# Current node is in region coordinates of [146, 147, 3]
# Found Solution
# Animating Search Pattern

# %%
plt.figure(figsize=(10, 10))
plt.imshow(color_map, origin = "bottom")

# %%
import rospy
from geometry_msgs.msg import Point, Twist
import time
import math
from nav_msgs.msg import Odometry
def calc_vels(node):
    RPM_R = 25
    RPM_L = 25
    RAD_T = 0.033 #meters
    L_T = 0.35
    count = 0
    rospy.init_node('project3_p2')
    cmd_vel = rospy.Publisher('cmd_vel', Twist, queue_size=10)

    # sub2 = rospy.Subscriber("/odom",Odometry,move_robot)
    # if count == 0:
    #     # rospy.init_node("/cmd_vel")
    #     move_cmd = Twist()
    #     move_cmd.linear.x = 0.5
    #     move_cmd.angular.z = 0
    #     # while x != node.cell_location[0] and y != node.cell_location[1]:
    #     # rospy.loginfo("Moving forward at ",move_cmd," velocities")
    #     cmd_vel.publish(move_cmd)
    #     rospy.sleep(1.1)
    #     # move_cmd.linear.x = 0
    #     # move_cmd.angular.z = 0
    #     # cmd_vel.publish(move_cmd)
    #     count += 1
    if node.command[0] == node.command[1]:
        # cmd_vel = rospy.Publisher('cmd_vel', Twist, queue_size=10)
        move_cmd = Twist()
        move_cmd.linear.x = 0.8
        move_cmd.angular.z = 0
        # while x != node.cell_location[0] and y != node.cell_location[1]:
        rospy.loginfo("Moving forward")
        cmd_vel.publish(move_cmd)
        rospy.sleep(1)
        # move_cmd.linear.x = 0

        # move_cmd.angular.z = 0
        # cmd_vel.publish(move_cmd)
    else:
        # dot_x = 1.24
        # dot_x = (RAD_T/2)*(node.command[0]+node.command[1])*abs(math.cos(node.cell_location[2]))
        # dot_y = (RAD_T/2)*(node.command[0]+node.command[1])*math.sin(node.cell_location[2])
        dot_x = 1
        # dot_y = 1*abs(math.sin(node.cell_location[2]))
        dot_theta =(RAD_T/L_T)*(node.command[0]-node.command[1])*2
        rospy.loginfo("Turning")
        move_cmd = Twist()
        move_cmd.linear.x = 0.8
        # move_cmd.linear.y = dot_y
        move_cmd.angular.z = dot_theta
        # while x != node.cell_location[0] and y != node.cell_location[1]:
        # rospy.loginfo("Moving forward and turning at ",move_cmd," velocities")
        cmd_vel.publish(move_cmd)
        rospy.sleep(1)
        # move_cmd.linear.x = 0
        # # move_cmd.linear.y = 0
        # move_cmd.angular.z = 0
        # cmd_vel.publish(move_cmd)
# with open("/home/nick/catkin_ws/src/project3_p2/src/sol_path.txt",'r') as all_paths:
    # print("Here")
def stop_bot():
    cmd_vel = rospy.Publisher('cmd_vel', Twist, queue_size=10)
    move_cmd = Twist()
    move_cmd.linear.x = 0
    # move_cmd.linear.y = 0
    move_cmd.angular.z = 0
    cmd_vel.publish(move_cmd)


# for command in commands:
#     calc_vl
class Node2:
    def __init__(self,cell_location,command):
        self.cell_location = cell_location
        self.command = command
count = 0
for node in solution_path:
    node = Node2(node[0],node[1])
    if count == 0:
        count+=1
        
    else:
        calc_vels(node)
        rospy.loginfo("Moving to location: "+str(node.cell_location[0]/20)+" "+str(node.cell_location[1]/20)+" "+str(node.cell_location[2])+"with command "+str(node.command))
rospy.loginfo("Success!")
stop_bot()

    # print(str([node.cell_location,node.command]))
# Wrong MAP
